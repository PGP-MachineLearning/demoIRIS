# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation usando clases de Keras para identificar TIPOS de Flores IRIS
# Adaptado de https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
import keras
from keras.layers import Input, Dense
from keras.layers import Conv1D, MaxPooling1D
from keras.layers import Reshape, Flatten, Dropout
from keras.models import Model
from keras.utils import plot_model
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Cargar los datos:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = '/content/gdrive/My Drive/IA/demo IRIS'  #@param {type:"string"}
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
## selección de los parámetros 

#@markdown ### Archivo de datos a utilizar:
archivo_datos = '/datos/IRIS.csv'  #@param {type:"string"}
#@markdown ### Nombre del atributo clase / objetivo:
atributo_clase = 'Clase' #@param {type:"string"}
#@markdown ### Descripción de los valores del atributo clase / objetivo:  (nota: siempre debe comienzar en 0, por lo que si no tiene valor 0, agregar "na")
nombre_clases = 'na, Setosa, Versicolor, Virginica' #@param {type:"string"}
#@markdown ### Porcentaje de datos para usar en el entrenamiento:
proporcion_porcentaje_datos_entrenamiento =   70#@param {type:"integer"}

## aplicación de los parámetros elegidos

# define nombre atributo de CLASE para ejemplo IRIS
ClassAttributeName = atributo_clase

# define valores de clases para ejemplo IRIS
CLASES = [ ]
for val in nombre_clases.split(','):
  CLASES.append( val )

# determina la proporción a usar para entrenar y probar
if proporcion_porcentaje_datos_entrenamiento>100:
  propTrain = 1
elif proporcion_porcentaje_datos_entrenamiento<1:
  propTrain = 0.1
else:
  propTrain = proporcion_porcentaje_datos_entrenamiento/100

print("Configuración definida de ", archivo_datos)
print("Atributo clase: ", ClassAttributeName, ": ", CLASES)
# Out:
# Configuración definida de  /datos/IRIS.csv
# Atributo clase:  Clase :  ['na', ' Setosa', ' Versicolor', ' Virginica']

# %%
#@title Cargar datos

# configura para que muestre todas las columnas y filas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# Carga los datos del CSV y muestra los primeros
df = pd.read_csv(path + archivo_datos)
print("\n> Cabecera: ")
print(df.head())
print("\n> Características: ")
print(df.describe())

# genera los datos solo con la clase para entrenar y probar
Y = np.array(df.pop(ClassAttributeName))
X = np.array(df)
# Out:
# > Cabecera:
#    LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo  Clase
# 0          5.1          3.5          1.4          0.2      1
# 1          4.9          3.0          1.4          0.2      1
# 2          4.7          3.2          1.3          0.2      1
# 3          4.6          3.1          1.5          0.2      1
# 4          5.0          3.6          1.4          0.2      1
#
# > Características:
#        LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo       Clase
# count   150.000000   150.000000   150.000000   150.000000  150.000000
# mean      5.843333     3.054000     3.758667     1.198667    2.000000
# std       0.828066     0.433594     1.764420     0.763161    0.819232
# min       4.300000     2.000000     1.000000     0.100000    1.000000
# 25%       5.100000     2.800000     1.600000     0.300000    1.000000
# 50%       5.800000     3.000000     4.350000     1.300000    2.000000
# 75%       6.400000     3.300000     5.100000     1.800000    3.000000
# max       7.900000     4.400000     6.900000     2.500000    3.000000

# %%
#@title Normalizar datos de entrada (opcional)

print("10 primeros datos de Entrada antes de normalizar: ")
print(X[:10])

from sklearn import preprocessing

# elegir el método de normalización
scaler = preprocessing.MinMaxScaler()
#scaler = preprocessing.MaxAbsScaler()

# normaliza los datos de entrada
X = scaler.fit_transform(X)

print("\n\n10 primeros datos de Entrada después de normalizar: ")
print(X[:10])
# Out:
# 10 primeros datos de Entrada antes de normalizar:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]
#
#
# 10 primeros datos de Entrada después de normalizar:
# [[0.22222222 0.625      0.06779661 0.04166667]
#  [0.16666667 0.41666667 0.06779661 0.04166667]
#  [0.11111111 0.5        0.05084746 0.04166667]
#  [0.08333333 0.45833333 0.08474576 0.04166667]
#  [0.19444444 0.66666667 0.06779661 0.04166667]
#  [0.30555556 0.79166667 0.11864407 0.125     ]
#  [0.08333333 0.58333333 0.06779661 0.08333333]
#  [0.19444444 0.58333333 0.08474576 0.04166667]
#  [0.02777778 0.375      0.06779661 0.04166667]
#  [0.16666667 0.45833333 0.08474576 0.        ]]

# %%
#@title Preparar datos

# separa al azar usando muestreo estratificado con proporción indicada
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=(1-propTrain), stratify=Y)

# genera salida codificada para softMax
y_trainEnc =  np_utils.to_categorical(y_train)
y_testEnc =  np_utils.to_categorical(y_test)

# muestra resultados
print("> Para Ambos: ")
print(" - dictMapeo: ", CLASES)

print("\n> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
for i in range(len(CLASES)):
  cant = 0
  for y in y_train:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)

print("\n Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
for i in range(len(CLASES)):
  cant = 0
  for y in y_test:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)
# Out:
# > Para Ambos:
#  - dictMapeo:  ['na', ' Setosa', ' Versicolor', ' Virginica']
#
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (104, 4)
#  - y_train (cant):  104
#      na [ 0 ]: 0
#       Setosa [ 1 ]: 34
#       Versicolor [ 2 ]: 35
#       Virginica [ 3 ]: 35
#
#  Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (46, 4)
#  - y_test (cant):  46
#      na [ 0 ]: 0
#       Setosa [ 1 ]: 16
#       Versicolor [ 2 ]: 15
#       Virginica [ 3 ]: 15

# %%
#@title Preparar datos - convertir a matriz
cols = x_train.shape[1]

matrixShape = [2,(cols//2)]
print("\n Forma de la matriz: ", matrixShape)

matrixTrain = []
matrixTest = []

# cambia la forma de la matriz
matrixTrain = x_train.reshape((len(x_train), matrixShape[0], matrixShape[1]))  
matrixTest = x_test.reshape((len(x_test), matrixShape[0], matrixShape[1]))  

print("\n Datos de entrada convertidos matriz: ")
print(" - matrixTrain (cant ejemplos, forma): ", matrixTrain.shape)
print(" - matrixTest (cant ejemplos, forma): ", matrixTest.shape)
# Out:
#  Forma de la matriz:  [2, 2]
#
#  Datos de entrada convertidos matriz:
#  - matrixTrain (cant ejemplos, forma):  (104, 2, 2)
#  - matrixTest (cant ejemplos, forma):  (46, 2, 2)

# %% [markdown]
# 3) Establecer el modelo para la RNA

# %%
#@markdown ### Parámetros de la red:
cnn_tamaño_kernel = 3 #@param {type:"integer"}
cnn_tamaño_pooling = 2 #@param {type:"integer"}
cnn_cantidad_capas_ocultas = 5 #@param {type:"integer"}
cnn_cantidad_neuronas_Dense = 16 #@param {type:"integer"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento = 250 #@param {type:"integer"}

## aplicación de los parámetros elegidos

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", matrixShape, ", Conv", cnn_filters,  ", FLATTEN, Dense[", num_Dense_out, "], DROP-OUT, ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Kernels + Pooling: [ 3 + 2 ]
#      -Capas: [  [2, 2] , Conv [128, 64, 32, 16, 8] , FLATTEN, Dense[ 16 ], DROP-OUT,  Softmax

# %%
#@title Establecer modelo

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=((matrixShape[0], matrixShape[1])), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxId = 1 
for i in range(len(cnn_filters)):  
       
    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(auxId)
    auxId = auxId + 1

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv1D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling1D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
eachLay = Dense(num_Dense_out, activation='relu', name='d_'+auxlayerName)(eachLay)
eachLay = Dropout(0.5)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(CLASES), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
#model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  15  capas:
# Model: "RNA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 2, 2)]            0
# _________________________________________________________________
# c_conv_1 (Conv1D)            (None, 2, 128)            896
# _________________________________________________________________
# p_conv_1 (MaxPooling1D)      (None, 1, 128)            0
# _________________________________________________________________
# c_conv_2 (Conv1D)            (None, 1, 64)             24640
# _________________________________________________________________
# p_conv_2 (MaxPooling1D)      (None, 1, 64)             0
# _________________________________________________________________
# c_conv_3 (Conv1D)            (None, 1, 32)             6176
# _________________________________________________________________
# p_conv_3 (MaxPooling1D)      (None, 1, 32)             0
# _________________________________________________________________
# c_conv_4 (Conv1D)            (None, 1, 16)             1552
# _________________________________________________________________
# p_conv_4 (MaxPooling1D)      (None, 1, 16)             0
# _________________________________________________________________
# c_conv_5 (Conv1D)            (None, 1, 8)              392
# _________________________________________________________________
# p_conv_5 (MaxPooling1D)      (None, 1, 8)              0
# _________________________________________________________________
# flat_conv_5 (Flatten)        (None, 8)                 0
# _________________________________________________________________
# d_conv_5 (Dense)             (None, 16)                144
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# output (Dense)               (None, 4)                 68
# =================================================================
# Total params: 33,868
# Trainable params: 33,868
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(matrixTrain, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,) ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  104 ejemplos de entrenamiento:
#             se usan  93 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/250
# 3/3 [==============================] - 0s 85ms/step - loss: 1.3858 - accuracy: 0.2258 - val_loss: 1.3841 - val_accuracy: 0.1818
# Epoch 2/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3831 - accuracy: 0.3333 - val_loss: 1.3816 - val_accuracy: 0.1818
# Epoch 3/250
# 3/3 [==============================] - 0s 10ms/step - loss: 1.3808 - accuracy: 0.3118 - val_loss: 1.3794 - val_accuracy: 0.1818
# Epoch 4/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3782 - accuracy: 0.3548 - val_loss: 1.3767 - val_accuracy: 0.1818
# Epoch 5/250
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3759 - accuracy: 0.3656 - val_loss: 1.3743 - val_accuracy: 0.1818
# Epoch 6/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3726 - accuracy: 0.3548 - val_loss: 1.3714 - val_accuracy: 0.1818
# Epoch 7/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3685 - accuracy: 0.4086 - val_loss: 1.3682 - val_accuracy: 0.1818
# Epoch 8/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3660 - accuracy: 0.3656 - val_loss: 1.3648 - val_accuracy: 0.1818
# Epoch 9/250
# 3/3 [==============================] - 0s 9ms/step - loss: 1.3623 - accuracy: 0.3978 - val_loss: 1.3609 - val_accuracy: 0.1818
# Epoch 10/250
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3568 - accuracy: 0.3763 - val_loss: 1.3566 - val_accuracy: 0.1818
# Epoch 11/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3568 - accuracy: 0.3548 - val_loss: 1.3514 - val_accuracy: 0.1818
# Epoch 12/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3440 - accuracy: 0.4086 - val_loss: 1.3454 - val_accuracy: 0.1818
# Epoch 13/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3441 - accuracy: 0.3763 - val_loss: 1.3390 - val_accuracy: 0.1818
# Epoch 14/250
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3354 - accuracy: 0.4624 - val_loss: 1.3306 - val_accuracy: 0.1818
# Epoch 15/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3214 - accuracy: 0.3978 - val_loss: 1.3199 - val_accuracy: 0.1818
# Epoch 16/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3227 - accuracy: 0.3333 - val_loss: 1.3075 - val_accuracy: 0.1818
# Epoch 17/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3020 - accuracy: 0.4409 - val_loss: 1.2924 - val_accuracy: 0.1818
# Epoch 18/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1.2981 - accuracy: 0.4516 - val_loss: 1.2734 - val_accuracy: 0.1818
# Epoch 19/250
# 3/3 [==============================] - 0s 8ms/step - loss: 1
250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1504 - accuracy: 0.9355 - val_loss: 0.1355 - val_accuracy: 1.0000
# Epoch 145/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2527 - accuracy: 0.9140 - val_loss: 0.1206 - val_accuracy: 0.9091
# Epoch 146/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2156 - accuracy: 0.9355 - val_loss: 0.1801 - val_accuracy: 0.9091
# Epoch 147/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1778 - accuracy: 0.9355 - val_loss: 0.3886 - val_accuracy: 0.8182
# Epoch 148/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2174 - accuracy: 0.9355 - val_loss: 0.1149 - val_accuracy: 1.0000
# Epoch 149/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1667 - accuracy: 0.9570 - val_loss: 0.1073 - val_accuracy: 0.9091
# Epoch 150/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2194 - accuracy: 0.9355 - val_loss: 0.2693 - val_accuracy: 0.8182
# Epoch 151/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2054 - accuracy: 0.9462 - val_loss: 0.1078 - val_accuracy: 1.0000
# Epoch 152/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1355 - accuracy: 0.9785 - val_loss: 0.0887 - val_accuracy: 1.0000
# Epoch 153/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1935 - accuracy: 0.9785 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 154/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1991 - accuracy: 0.9355 - val_loss: 0.1932 - val_accuracy: 0.9091
# Epoch 155/250
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2467 - accuracy: 0.9355 - val_loss: 0.2704 - val_accuracy: 0.8182
# Epoch 156/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1945 - accuracy: 0.9570 - val_loss: 0.0897 - val_accuracy: 1.0000
# Epoch 157/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2154 - accuracy: 0.9677 - val_loss: 0.0907 - val_accuracy: 0.9091
# Epoch 158/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2034 - accuracy: 0.9570 - val_loss: 0.0992 - val_accuracy: 1.0000
# Epoch 159/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1706 - accuracy: 0.9677 - val_loss: 0.1811 - val_accuracy: 0.9091
# Epoch 160/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1805 - accuracy: 0.9570 - val_loss: 0.1527 - val_accuracy: 0.9091
# Epoch 161/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2713 - accuracy: 0.9140 - val_loss: 0.1279 - val_accuracy: 0.9091
# Epoch 162/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2222 - accuracy: 0.9677 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 163/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1794 - accuracy: 0.9677 - val_loss: 0.0914 - val_accuracy: 0.9091
# Epoch 164/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2083 - accuracy: 0.9247 - val_loss: 0.1041 - val_accuracy: 1.0000
# Epoch 165/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1705 - accuracy: 0.9677 - val_loss: 0.0943 - val_accuracy: 0.9091
# Epoch 166/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1908 - accuracy: 0.9677 - val_loss: 0.0864 - val_accuracy: 0.9091
# Epoch 167/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1859 - accuracy: 0.9570 - val_loss: 0.4157 - val_accuracy: 0.8182
# Epoch 168/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2476 - accuracy: 0.9462 - val_loss: 0.1783 - val_accuracy: 0.9091
# Epoch 169/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1301 - accuracy: 0.9785 - val_loss: 0.1069 - val_accuracy: 0.9091
# Epoch 170/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2398 - accuracy: 0.9355 - val_loss: 0.1672 - val_accuracy: 0.9091
# Epoch 171/250
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2109 - accuracy: 0.9677 - val_loss: 0.0813 - val_accuracy: 0.9091
# Epoch 172/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1844 - accuracy: 0.9677 - val_loss: 0.0963 - val_accuracy: 1.0000
# Epoch 173/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1379 - accuracy: 0.9785 - val_loss: 0.1675 - val_accuracy: 0.9091
# Epoch 174/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2455 - accuracy: 0.9032 - val_loss: 0.1071 - val_accuracy: 0.9091
# Epoch 175/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1878 - accuracy: 0.9462 - val_loss: 0.2242 - val_accuracy: 0.9091
# Epoch 176/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1481 - accuracy: 0.9570 - val_loss: 0.1347 - val_accuracy: 0.9091
# Epoch 177/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1402 - accuracy: 0.9677 - val_loss: 0.2580 - val_accuracy: 0.8182
# Epoch 178/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3099 - accuracy: 0.9032 - val_loss: 0.2751 - val_accuracy: 0.8182
# Epoch 179/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1334 - accuracy: 0.9570 - val_loss: 0.1140 - val_accuracy: 0.9091
# Epoch 180/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1546 - accuracy: 0.9570 - val_loss: 0.1941 - val_accuracy: 0.9091
# Epoch 181/250
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2358 - accuracy: 0.9032 - val_loss: 0.1003 - val_accuracy: 0.9091
# Epoch 182/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1634 - accuracy: 0.9677 - val_loss: 0.0775 - val_accuracy: 1.0000
# Epoch 183/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2670 - accuracy: 0.8925 - val_loss: 0.0745 - val_accuracy: 1.0000
# Epoch 184/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1724 - accuracy: 0.9462 - val_loss: 0.0927 - val_accuracy: 1.0000
# Epoch 185/250
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1665 - accuracy: 0.9785 - val_loss: 0.3328 - val_accuracy: 0.8182
# Epoch 186/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1461 - accuracy: 0.9677 - val_loss: 0.2904 - val_accuracy: 0.8182
# Epoch 187/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0944 - accuracy: 0.9892 - val_loss: 0.0978 - val_accuracy: 1.0000
# Epoch 188/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2387 - accuracy: 0.9355 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 189/250
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1050 - accuracy: 0.9892 - val_loss: 0.0759 - val_accuracy: 1.0000
# Epoch 190/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1516 - accuracy: 0.9570 - val_loss: 0.3217 - val_accuracy: 0.8182
# Epoch 191/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1281 - accuracy: 1.0000 - val_loss: 0.4147 - val_accuracy: 0.8182
# Epoch 192/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1969 - accuracy: 0.9355 - val_loss: 0.0742 - val_accuracy: 1.0000
# Epoch 193/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2074 - accuracy: 0.9355 - val_loss: 0.0911 - val_accuracy: 0.9091
# Epoch 194/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1516 - accuracy: 0.9355 - val_loss: 0.0734 - val_accuracy: 0.9091
# Epoch 195/250
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1879 - accuracy: 0.9355 - val_loss: 0.2567 - val_accuracy: 0.8182
# Epoch 196/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1936 - accuracy: 0.9677 - val_loss: 0.2629 - val_accuracy: 0.8182
# Epoch 197/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1643 - accuracy: 0.9570 - val_loss: 0.0646 - val_accuracy: 1.0000
# Epoch 198/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1731 - accuracy: 0.9677 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 199/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1617 - accuracy: 0.9785 - val_loss: 0.1310 - val_accuracy: 0.9091
# Epoch 200/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1187 - accuracy: 0.9892 - val_loss: 0.1551 - val_accuracy: 0.9091
# Epoch 201/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1804 - accuracy: 0.9462 - val_loss: 0.1715 - val_accuracy: 0.9091
# Epoch 202/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1956 - accuracy: 0.9570 - val_loss: 0.2842 - val_accuracy: 0.8182
# Epoch 203/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1330 - accuracy: 0.9785 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 204/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1663 - accuracy: 0.9892 - val_loss: 0.0981 - val_accuracy: 0.9091
# Epoch 205/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2428 - accuracy: 0.9140 - val_loss: 0.0771 - val_accuracy: 0.9091
# Epoch 206/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2198 - accuracy: 0.9140 - val_loss: 0.0738 - val_accuracy: 1.0000
# Epoch 207/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1293 - accuracy: 0.9892 - val_loss: 0.2052 - val_accuracy: 0.8182
# Epoch 208/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1560 - accuracy: 0.9462 - val_loss: 0.2335 - val_accuracy: 0.8182
# Epoch 209/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2559 - accuracy: 0.9355 - val_loss: 0.0894 - val_accuracy: 1.0000
# Epoch 210/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1764 - accuracy: 0.9462 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 211/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1820 - accuracy: 0.9570 - val_loss: 0.1291 - val_accuracy: 0.9091
# Epoch 212/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1102 - accuracy: 0.9677 - val_loss: 0.7024 - val_accuracy: 0.8182
# Epoch 213/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1783 - accuracy: 0.9570 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 214/250
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1474 - accuracy: 0.9677 - val_loss: 0.0709 - val_accuracy: 0.9091
# Epoch 215/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2142 - accuracy: 0.9247 - val_loss: 0.0870 - val_accuracy: 0.9091
# Epoch 216/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1370 - accuracy: 0.9570 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 217/250
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2350 - accuracy: 0.9462 - val_loss: 0.2355 - val_accuracy: 0.8182
# Epoch 218/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0688 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 1.0000
# Epoch 219/250
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2364 - accuracy: 0.9570 - val_loss: 0.0401 - val_accuracy: 1.0000
# Epoch 220/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1879 - accuracy: 0.9355 - val_loss: 0.0870 - val_accuracy: 0.9091
# Epoch 221/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2194 - accuracy: 0.9570 - val_loss: 0.1232 - val_accuracy: 1.0000
# Epoch 222/250
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1699 - accuracy: 0.9677 - val_loss: 0.4863 - val_accuracy: 0.8182
# Epoch 223/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2026 - accuracy: 0.9570 - val_loss: 0.2464 - val_accuracy: 0.8182
# Epoch 224/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1890 - accuracy: 0.9570 - val_loss: 0.0409 - val_accuracy: 1.0000
# Epoch 225/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1198 - accuracy: 0.9892 - val_loss: 0.1269 - val_accuracy: 0.9091
# Epoch 226/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1477 - accuracy: 0.9785 - val_loss: 0.1072 - val_accuracy: 0.9091
# Epoch 227/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1366 - accuracy: 1.0000 - val_loss: 0.0323 - val_accuracy: 1.0000
# Epoch 228/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1471 - accuracy: 0.9677 - val_loss: 0.4105 - val_accuracy: 0.8182
# Epoch 229/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1693 - accuracy: 0.9570 - val_loss: 0.4088 - val_accuracy: 0.8182
# Epoch 230/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1038 - accuracy: 0.9785 - val_loss: 0.1933 - val_accuracy: 0.8182
# Epoch 231/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2408 - accuracy: 0.9462 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 232/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1393 - accuracy: 0.9892 - val_loss: 0.0325 - val_accuracy: 1.0000
# Epoch 233/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1274 - accuracy: 0.9462 - val_loss: 0.0620 - val_accuracy: 1.0000
# Epoch 234/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2371 - accuracy: 0.9140 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 235/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1484 - accuracy: 0.9785 - val_loss: 0.0541 - val_accuracy: 1.0000
# Epoch 236/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1225 - accuracy: 0.9462 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 237/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1726 - accuracy: 0.9677 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 238/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1517 - accuracy: 0.9570 - val_loss: 0.0362 - val_accuracy: 1.0000
# Epoch 239/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1829 - accuracy: 0.9247 - val_loss: 0.1625 - val_accuracy: 0.8182
# Epoch 240/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1494 - accuracy: 0.9677 - val_loss: 0.1971 - val_accuracy: 0.8182
# Epoch 241/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1444 - accuracy: 0.9570 - val_loss: 0.0991 - val_accuracy: 1.0000
# Epoch 242/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2093 - accuracy: 0.9355 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 243/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1297 - accuracy: 0.9677 - val_loss: 0.0254 - val_accuracy: 1.0000
# Epoch 244/250
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2046 - accuracy: 0.9355 - val_loss: 0.0411 - val_accuracy: 1.0000
# Epoch 245/250
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1586 - accuracy: 0.9570 - val_loss: 0.0259 - val_accuracy: 1.0000
# Epoch 246/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1255 - accuracy: 0.9785 - val_loss: 0.0859 - val_accuracy: 1.0000
# Epoch 247/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0823 - accuracy: 0.9892 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 248/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1558 - accuracy: 0.9462 - val_loss: 0.0552 - val_accuracy: 1.0000
# Epoch 249/250
# 3/3 [==============================] - 0s 11ms/step - loss: 0.1716 - accuracy: 0.9462 - val_loss: 0.2344 - val_accuracy: 0.8182
# Epoch 250/250
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1937 - accuracy: 0.9570 - val_loss: 0.7112 - val_accuracy: 0.8182
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA"
        else:      
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / RNA: ' 
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'   
        strTitulo = strTitulo + ": " + ("ok" if (clPred==clReal) else "error!")

        # muestra comparación con la imagen
        print(strTitulo)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    # agrega para poder mostrar la matrix de confusión completa
    pd.options.display.max_rows = 100
    pd.options.display.max_columns = 100
    print(cmtx)
    print("\n")

    # gráfico de comparación
    plt.title('Gráfico de Confusión:')
    plt.xlabel('Real')
    plt.ylabel('RNA')
    plt.scatter(classReal, classPreds)

# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(matrixTrain, y_train, CLASES)
# Out:
# *** Resultados con datos de Entrenamiento:
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Versicolor (2): error!
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Versicolor (2): error!
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Versicolor (2): error!
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Versicolor (2): error!
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        34
#   Versicolor       0.90      1.00      0.95        35
#    Virginica       1.00      0.89      0.94        35
#
#     accuracy                           0.96       104
#    macro avg       0.97      0.96      0.96       104
# weighted avg       0.97      0.96      0.96       104
#
#
# Matriz de Confusión:
#                p:na  p: Setosa  p: Versicolor  p: Virginica
# r:na              0          0              0             0
# r: Setosa         0         34              0             0
# r: Versicolor     0          0             35             0
# r: Virginica      0          0              4            31

# %% [markdown]
# 6) Evaluar el modelo de la RNA entrenado con los datos de prueba:

# %%
 #@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(matrixTest, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de prueba
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(matrixTest, y_test, CLASES)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1747 - accuracy: 0.9565
#
# >Evaluación del Modelo:
#     - Error:  0.1747456043958664
#     - Exactitud:  95.652174949646
#
#
#
#
# *** Resultados con datos de Prueba:
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Versicolor (2): error!
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Virginica (3): error!
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        16
#   Versicolor       0.93      0.93      0.93        15
#    Virginica       0.93      0.93      0.93        15
#
#     accuracy                           0.96        46
#    macro avg       0.96      0.96      0.96        46
# weighted avg       0.96      0.96      0.96        46
#
#
# Matriz de Confusión:
#                p:na  p: Setosa  p: Versicolor  p: Virginica
# r:na              0          0              0             0
# r: Setosa         0         16              0             0
# r: Versicolor     0          0             14             1
# r: Virginica      0          0              1            14
