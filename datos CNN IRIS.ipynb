# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation usando clases de Keras para identificar TIPOS de Flores IRIS
# Adaptado de https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
import keras
from keras.layers import Input, Dense
from keras.layers import Conv1D, MaxPooling1D
from keras.layers import Reshape, Flatten, Dropout
from keras.models import Model
from keras.utils import plot_model
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Cargar los datos:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')

# directorio local en Google Drive
path = '/content/gdrive/My Drive/IA/demo IRIS'  #@param {type:"string"}
# Out:
# Mounted at /content/gdrive

# %%
## selección de los parámetros 

#@markdown ### Archivo de datos a utilizar:
archivo_datos = '/datos/IRIS.csv'  #@param {type:"string"}
#@markdown ### Nombre del atributo clase / objetivo:
atributo_clase = 'Clase' #@param {type:"string"}
#@markdown ### Descripción de los valores del atributo clase / objetivo:  (nota: siempre debe comienzar en 0, por lo que si no tiene valor 0, agregar "na")
nombre_clases = 'na, Setosa, Versicolor, Virginica' #@param {type:"string"}
#@markdown ### Porcentaje de datos para usar en el entrenamiento:
proporcion_porcentaje_datos_entrenamiento =   70#@param {type:"integer"}

## aplicación de los parámetros elegidos

# define nombre atributo de CLASE para ejemplo IRIS
ClassAttributeName = atributo_clase

# define valores de clases para ejemplo IRIS
CLASES = [ ]
for val in nombre_clases.split(','):
  CLASES.append( val )

# determina la proporción a usar para entrenar y probar
if proporcion_porcentaje_datos_entrenamiento>100:
  propTrain = 1
elif proporcion_porcentaje_datos_entrenamiento<1:
  propTrain = 0.1
else:
  propTrain = proporcion_porcentaje_datos_entrenamiento/100

print("Configuración definida de ", archivo_datos)
print("Atributo clase: ", ClassAttributeName, ": ", CLASES)
# Out:
# Configuración definida de  /datos/IRIS.csv
# Atributo clase:  Clase :  ['na', ' Setosa', ' Versicolor', ' Virginica']

# %%
#@title Cargar datos

# configura para que muestre todas las columnas y filas
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# Carga los datos del CSV y muestra los primeros
df = pd.read_csv(path + archivo_datos)
print("\n> Cabecera: ")
print(df.head())
print("\n> Características: ")
print(df.describe())

# genera los datos solo con la clase para entrenar y probar
Y = np.array(df.pop(ClassAttributeName))
X = np.array(df)
# Out:
# > Cabecera:
#    LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo  Clase
# 0          5.1          3.5          1.4          0.2      1
# 1          4.9          3.0          1.4          0.2      1
# 2          4.7          3.2          1.3          0.2      1
# 3          4.6          3.1          1.5          0.2      1
# 4          5.0          3.6          1.4          0.2      1
#
# > Características:
#        LargoSepalo  AnchoSepalo  LargoPetalo  AnchoPetalo       Clase
# count   150.000000   150.000000   150.000000   150.000000  150.000000
# mean      5.843333     3.054000     3.758667     1.198667    2.000000
# std       0.828066     0.433594     1.764420     0.763161    0.819232
# min       4.300000     2.000000     1.000000     0.100000    1.000000
# 25%       5.100000     2.800000     1.600000     0.300000    1.000000
# 50%       5.800000     3.000000     4.350000     1.300000    2.000000
# 75%       6.400000     3.300000     5.100000     1.800000    3.000000
# max       7.900000     4.400000     6.900000     2.500000    3.000000

# %%
#@title Normalizar datos de entrada (opcional)

print("10 primeros datos de Entrada antes de normalizar: ")
print(X[:10])

from sklearn import preprocessing

# elegir el método de normalización
scaler = preprocessing.MinMaxScaler()
#scaler = preprocessing.MaxAbsScaler()

# normaliza los datos de entrada
X = scaler.fit_transform(X)

print("\n\n10 primeros datos de Entrada después de normalizar: ")
print(X[:10])
# Out:
# 10 primeros datos de Entrada antes de normalizar:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]
#
#
# 10 primeros datos de Entrada después de normalizar:
# [[0.22222222 0.625      0.06779661 0.04166667]
#  [0.16666667 0.41666667 0.06779661 0.04166667]
#  [0.11111111 0.5        0.05084746 0.04166667]
#  [0.08333333 0.45833333 0.08474576 0.04166667]
#  [0.19444444 0.66666667 0.06779661 0.04166667]
#  [0.30555556 0.79166667 0.11864407 0.125     ]
#  [0.08333333 0.58333333 0.06779661 0.08333333]
#  [0.19444444 0.58333333 0.08474576 0.04166667]
#  [0.02777778 0.375      0.06779661 0.04166667]
#  [0.16666667 0.45833333 0.08474576 0.        ]]

# %%
#@title Preparar datos

# separa al azar usando muestreo estratificado con proporción indicada
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=(1-propTrain), stratify=Y)

# genera salida codificada para softMax
y_trainEnc =  np_utils.to_categorical(y_train)
y_testEnc =  np_utils.to_categorical(y_test)

# muestra resultados
print("> Para Ambos: ")
print(" - dictMapeo: ", CLASES)

print("\n> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
print(" - y_train (cant): ", len(y_train))
for i in range(len(CLASES)):
  cant = 0
  for y in y_train:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)

print("\n Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
print(" - y_test (cant): ", len(y_test))
for i in range(len(CLASES)):
  cant = 0
  for y in y_test:
    if i == y: cant = cant + 1
  print("    ", CLASES[i], "[", i, "]:", cant)
# Out:
# > Para Ambos:
#  - dictMapeo:  ['na', ' Setosa', ' Versicolor', ' Virginica']
#
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (104, 4)
#  - y_train (cant):  104
#      na [ 0 ]: 0
#       Setosa [ 1 ]: 35
#       Versicolor [ 2 ]: 34
#       Virginica [ 3 ]: 35
#
#  Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (46, 4)
#  - y_test (cant):  46
#      na [ 0 ]: 0
#       Setosa [ 1 ]: 15
#       Versicolor [ 2 ]: 16
#       Virginica [ 3 ]: 15

# %%
#@title Preparar datos - convertir a matriz
cols = x_train.shape[1]

matrixShape = [2,(cols//2)]
print("\n Forma de la matriz: ", matrixShape)

matrixTrain = []
matrixTest = []

# cambia la forma de la matriz
matrixTrain = x_train.reshape((len(x_train), matrixShape[0], matrixShape[1]))  
matrixTest = x_test.reshape((len(x_test), matrixShape[0], matrixShape[1]))  

print("\n Datos de entrada convertidos matriz: ")
print(" - matrixTrain (cant ejemplos, forma): ", matrixTrain.shape)
print(" - matrixTest (cant ejemplos, forma): ", matrixTest.shape)
# Out:
#  Forma de la matriz:  [2, 2]
#
#  Datos de entrada convertidos matriz:
#  - matrixTrain (cant ejemplos, forma):  (104, 2, 2)
#  - matrixTest (cant ejemplos, forma):  (46, 2, 2)

# %% [markdown]
# 3) Establecer el modelo para la RNA

# %%
#@markdown ### Parámetros de la red:
cnn_tamaño_kernel = 3 #@param {type:"integer"}
cnn_tamaño_pooling = 2 #@param {type:"integer"}
cnn_cantidad_capas_ocultas = 5 #@param {type:"integer"}
cnn_cantidad_neuronas_Dense = 16 #@param {type:"integer"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento = 250 #@param {type:"integer"}

## aplicación de los parámetros elegidos

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", matrixShape, ", Conv", cnn_filters,  ", FLATTEN, Dense[", num_Dense_out, "], DROP-OUT, ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Kernels + Pooling: [ 3 + 2 ]
#      -Capas: [  [2, 2] , Conv [128, 64, 32, 16, 8] , FLATTEN, Dense[ 16 ], DROP-OUT,  Softmax

# %%
#@title Establecer modelo

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=((matrixShape[0], matrixShape[1])), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxId = 1 
for i in range(len(cnn_filters)):  
       
    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(auxId)
    auxId = auxId + 1

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv1D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling1D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
eachLay = Dense(num_Dense_out, activation='relu', name='d_'+auxlayerName)(eachLay)
eachLay = Dropout(0.5)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(CLASES), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
#model.compile(optimizer='rmsprop', loss='mse', metrics=['accuracy'])
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  15  capas:
# Model: "RNA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 2, 2)]            0
# _________________________________________________________________
# c_conv_1 (Conv1D)            (None, 2, 128)            896
# _________________________________________________________________
# p_conv_1 (MaxPooling1D)      (None, 1, 128)            0
# _________________________________________________________________
# c_conv_2 (Conv1D)            (None, 1, 64)             24640
# _________________________________________________________________
# p_conv_2 (MaxPooling1D)      (None, 1, 64)             0
# _________________________________________________________________
# c_conv_3 (Conv1D)            (None, 1, 32)             6176
# _________________________________________________________________
# p_conv_3 (MaxPooling1D)      (None, 1, 32)             0
# _________________________________________________________________
# c_conv_4 (Conv1D)            (None, 1, 16)             1552
# _________________________________________________________________
# p_conv_4 (MaxPooling1D)      (None, 1, 16)             0
# _________________________________________________________________
# c_conv_5 (Conv1D)            (None, 1, 8)              392
# _________________________________________________________________
# p_conv_5 (MaxPooling1D)      (None, 1, 8)              0
# _________________________________________________________________
# flat_conv_5 (Flatten)        (None, 8)                 0
# _________________________________________________________________
# d_conv_5 (Dense)             (None, 16)                144
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# output (Dense)               (None, 4)                 68
# =================================================================
# Total params: 33,868
# Trainable params: 33,868
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(matrixTrain, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,) ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  104 ejemplos de entrenamiento:
#             se usan  93 ejemplos para entrenar
#             y  11 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/250
# 3/3 [==============================] - 2s 309ms/step - loss: 1.3852 - accuracy: 0.2579 - val_loss: 1.3759 - val_accuracy: 0.2727
# Epoch 2/250
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3766 - accuracy: 0.3410 - val_loss: 1.3661 - val_accuracy: 0.5455
# Epoch 3/250
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3714 - accuracy: 0.3424 - val_loss: 1.3551 - val_accuracy: 0.5455
# Epoch 4/250
# 3/3 [==============================] - 0s 22ms/step - loss: 1.3687 - accuracy: 0.2960 - val_loss: 1.3432 - val_accuracy: 0.5455
# Epoch 5/250
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3527 - accuracy: 0.3420 - val_loss: 1.3297 - val_accuracy: 0.5455
# Epoch 6/250
# 3/3 [==============================] - 0s 20ms/step - loss: 1.3421 - accuracy: 0.3503 - val_loss: 1.3136 - val_accuracy: 0.5455
# Epoch 7/250
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3318 - accuracy: 0.2340 - val_loss: 1.2991 - val_accuracy: 0.5455
# Epoch 8/250
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3217 - accuracy: 0.3664 - val_loss: 1.2825 - val_accuracy: 0.5455
# Epoch 9/250
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3258 - accuracy: 0.2618 - val_loss: 1.2663 - val_accuracy: 0.5455
# Epoch 10/250
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3001 - accuracy: 0.3293 - val_loss: 1.2476 - val_accuracy: 0.5455
# Epoch 11/250
# 3/3 [==============================] - 0s 21ms/step - loss: 1.
250
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2347 - accuracy: 0.9131 - val_loss: 0.2717 - val_accuracy: 0.9091
# Epoch 161/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2165 - accuracy: 0.9072 - val_loss: 0.1867 - val_accuracy: 0.9091
# Epoch 162/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1576 - accuracy: 0.9233 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 163/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2514 - accuracy: 0.8642 - val_loss: 0.1844 - val_accuracy: 0.9091
# Epoch 164/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2078 - accuracy: 0.8828 - val_loss: 0.3702 - val_accuracy: 0.9091
# Epoch 165/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2627 - accuracy: 0.8427 - val_loss: 0.2696 - val_accuracy: 0.9091
# Epoch 166/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1808 - accuracy: 0.9365 - val_loss: 0.0508 - val_accuracy: 1.0000
# Epoch 167/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2277 - accuracy: 0.8979 - val_loss: 0.0485 - val_accuracy: 1.0000
# Epoch 168/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1686 - accuracy: 0.9345 - val_loss: 0.2279 - val_accuracy: 0.9091
# Epoch 169/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1935 - accuracy: 0.9126 - val_loss: 0.3035 - val_accuracy: 0.9091
# Epoch 170/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2013 - accuracy: 0.9218 - val_loss: 0.1196 - val_accuracy: 0.9091
# Epoch 171/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1484 - accuracy: 0.9575 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 172/250
# 3/3 [==============================] - 0s 29ms/step - loss: 0.1816 - accuracy: 0.9629 - val_loss: 0.1790 - val_accuracy: 0.9091
# Epoch 173/250
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1288 - accuracy: 0.9365 - val_loss: 0.3131 - val_accuracy: 0.9091
# Epoch 174/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.3229 - accuracy: 0.8588 - val_loss: 0.2521 - val_accuracy: 0.9091
# Epoch 175/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2396 - accuracy: 0.9047 - val_loss: 0.1092 - val_accuracy: 0.9091
# Epoch 176/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1565 - accuracy: 0.9311 - val_loss: 0.0868 - val_accuracy: 0.9091
# Epoch 177/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2197 - accuracy: 0.8823 - val_loss: 0.2081 - val_accuracy: 0.9091
# Epoch 178/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1523 - accuracy: 0.9365 - val_loss: 0.2484 - val_accuracy: 0.9091
# Epoch 179/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0971 - accuracy: 0.9761 - val_loss: 0.2000 - val_accuracy: 0.9091
# Epoch 180/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1970 - accuracy: 0.9419 - val_loss: 0.0366 - val_accuracy: 1.0000
# Epoch 181/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2005 - accuracy: 0.9111 - val_loss: 0.0974 - val_accuracy: 0.9091
# Epoch 182/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1727 - accuracy: 0.9116 - val_loss: 0.3681 - val_accuracy: 0.9091
# Epoch 183/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2101 - accuracy: 0.9248 - val_loss: 0.4090 - val_accuracy: 0.9091
# Epoch 184/250
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2867 - accuracy: 0.8964 - val_loss: 0.2638 - val_accuracy: 0.9091
# Epoch 185/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1978 - accuracy: 0.9394 - val_loss: 0.0197 - val_accuracy: 1.0000
# Epoch 186/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2679 - accuracy: 0.8608 - val_loss: 0.0541 - val_accuracy: 1.0000
# Epoch 187/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2273 - accuracy: 0.8603 - val_loss: 0.3314 - val_accuracy: 0.9091
# Epoch 188/250
# 3/3 [==============================] - 0s 27ms/step - loss: 0.2382 - accuracy: 0.8984 - val_loss: 0.3131 - val_accuracy: 0.9091
# Epoch 189/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1358 - accuracy: 0.9350 - val_loss: 0.1823 - val_accuracy: 0.9091
# Epoch 190/250
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2224 - accuracy: 0.8901 - val_loss: 0.0482 - val_accuracy: 1.0000
# Epoch 191/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2394 - accuracy: 0.8412 - val_loss: 0.1564 - val_accuracy: 0.9091
# Epoch 192/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1146 - accuracy: 0.9746 - val_loss: 0.2948 - val_accuracy: 0.9091
# Epoch 193/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2651 - accuracy: 0.9101 - val_loss: 0.2563 - val_accuracy: 0.9091
# Epoch 194/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3048 - accuracy: 0.8334 - val_loss: 0.2044 - val_accuracy: 0.9091
# Epoch 195/250
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2041 - accuracy: 0.8994 - val_loss: 0.1515 - val_accuracy: 0.9091
# Epoch 196/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1587 - accuracy: 0.9321 - val_loss: 0.1185 - val_accuracy: 0.9091
# Epoch 197/250
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1676 - accuracy: 0.9165 - val_loss: 0.1662 - val_accuracy: 0.9091
# Epoch 198/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1401 - accuracy: 0.9458 - val_loss: 0.1824 - val_accuracy: 0.9091
# Epoch 199/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2004 - accuracy: 0.9101 - val_loss: 0.1240 - val_accuracy: 0.9091
# Epoch 200/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1667 - accuracy: 0.9170 - val_loss: 0.1579 - val_accuracy: 0.9091
# Epoch 201/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2067 - accuracy: 0.9047 - val_loss: 0.1426 - val_accuracy: 0.9091
# Epoch 202/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1544 - accuracy: 0.9800 - val_loss: 0.2303 - val_accuracy: 0.9091
# Epoch 203/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1432 - accuracy: 0.9551 - val_loss: 0.1478 - val_accuracy: 0.9091
# Epoch 204/250
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2073 - accuracy: 0.9165 - val_loss: 0.1853 - val_accuracy: 0.9091
# Epoch 205/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1627 - accuracy: 0.9853 - val_loss: 0.2176 - val_accuracy: 0.9091
# Epoch 206/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2185 - accuracy: 0.9155 - val_loss: 0.1762 - val_accuracy: 0.9091
# Epoch 207/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1532 - accuracy: 0.9311 - val_loss: 0.1418 - val_accuracy: 0.9091
# Epoch 208/250
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1227 - accuracy: 0.9458 - val_loss: 0.1697 - val_accuracy: 0.9091
# Epoch 209/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2793 - accuracy: 0.9101 - val_loss: 0.1264 - val_accuracy: 0.9091
# Epoch 210/250
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1880 - accuracy: 0.9116 - val_loss: 0.1992 - val_accuracy: 0.9091
# Epoch 211/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2007 - accuracy: 0.8984 - val_loss: 0.2674 - val_accuracy: 0.9091
# Epoch 212/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2418 - accuracy: 0.8999 - val_loss: 0.1889 - val_accuracy: 0.9091
# Epoch 213/250
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1660 - accuracy: 0.9008 - val_loss: 0.1639 - val_accuracy: 0.9091
# Epoch 214/250
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1429 - accuracy: 0.9272 - val_loss: 0.1344 - val_accuracy: 0.9091
# Epoch 215/250
# 3/3 [==============================] - 0s 28ms/step - loss: 0.1236 - accuracy: 0.9629 - val_loss: 0.1578 - val_accuracy: 0.9091
# Epoch 216/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1450 - accuracy: 0.9365 - val_loss: 0.2260 - val_accuracy: 0.9091
# Epoch 217/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1134 - accuracy: 0.9311 - val_loss: 0.2529 - val_accuracy: 0.9091
# Epoch 218/250
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1690 - accuracy: 0.9243 - val_loss: 0.2289 - val_accuracy: 0.9091
# Epoch 219/250
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1605 - accuracy: 0.9341 - val_loss: 0.1865 - val_accuracy: 0.9091
# Epoch 220/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2413 - accuracy: 0.9116 - val_loss: 0.1988 - val_accuracy: 0.9091
# Epoch 221/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1538 - accuracy: 0.9311 - val_loss: 0.1502 - val_accuracy: 0.9091
# Epoch 222/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3236 - accuracy: 0.8544 - val_loss: 0.1182 - val_accuracy: 0.9091
# Epoch 223/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1555 - accuracy: 0.9668 - val_loss: 0.2473 - val_accuracy: 0.9091
# Epoch 224/250
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2587 - accuracy: 0.8930 - val_loss: 0.1419 - val_accuracy: 0.9091
# Epoch 225/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1586 - accuracy: 0.9350 - val_loss: 0.1588 - val_accuracy: 0.9091
# Epoch 226/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2880 - accuracy: 0.8388 - val_loss: 0.1517 - val_accuracy: 0.9091
# Epoch 227/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2017 - accuracy: 0.8930 - val_loss: 0.0734 - val_accuracy: 0.9091
# Epoch 228/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1122 - accuracy: 0.9482 - val_loss: 0.1027 - val_accuracy: 0.9091
# Epoch 229/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2366 - accuracy: 0.8505 - val_loss: 0.2176 - val_accuracy: 0.9091
# Epoch 230/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1747 - accuracy: 0.9551 - val_loss: 0.2647 - val_accuracy: 0.9091
# Epoch 231/250
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1705 - accuracy: 0.9311 - val_loss: 0.2007 - val_accuracy: 0.9091
# Epoch 232/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1885 - accuracy: 0.9287 - val_loss: 0.0330 - val_accuracy: 1.0000
# Epoch 233/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1477 - accuracy: 0.9296 - val_loss: 0.1809 - val_accuracy: 0.9091
# Epoch 234/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2198 - accuracy: 0.8774 - val_loss: 0.2769 - val_accuracy: 0.9091
# Epoch 235/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2217 - accuracy: 0.9287 - val_loss: 0.2852 - val_accuracy: 0.9091
# Epoch 236/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1725 - accuracy: 0.9472 - val_loss: 0.1466 - val_accuracy: 0.9091
# Epoch 237/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2186 - accuracy: 0.8745 - val_loss: 0.0835 - val_accuracy: 0.9091
# Epoch 238/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1313 - accuracy: 0.9287 - val_loss: 0.1662 - val_accuracy: 0.9091
# Epoch 239/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2303 - accuracy: 0.9116 - val_loss: 0.1718 - val_accuracy: 0.9091
# Epoch 240/250
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1329 - accuracy: 0.9326 - val_loss: 0.1614 - val_accuracy: 0.9091
# Epoch 241/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1705 - accuracy: 0.9326 - val_loss: 0.1859 - val_accuracy: 0.9091
# Epoch 242/250
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1266 - accuracy: 0.9560 - val_loss: 0.1763 - val_accuracy: 0.9091
# Epoch 243/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2340 - accuracy: 0.9023 - val_loss: 0.1581 - val_accuracy: 0.9091
# Epoch 244/250
# 3/3 [==============================] - 0s 26ms/step - loss: 0.1810 - accuracy: 0.9047 - val_loss: 0.1580 - val_accuracy: 0.9091
# Epoch 245/250
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1683 - accuracy: 0.8969 - val_loss: 0.1820 - val_accuracy: 0.9091
# Epoch 246/250
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1293 - accuracy: 0.9629 - val_loss: 0.2283 - val_accuracy: 0.9091
# Epoch 247/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1806 - accuracy: 0.9458 - val_loss: 0.1141 - val_accuracy: 0.9091
# Epoch 248/250
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1611 - accuracy: 0.9272 - val_loss: 0.0421 - val_accuracy: 1.0000
# Epoch 249/250
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1866 - accuracy: 0.9170 - val_loss: 0.2264 - val_accuracy: 0.9091
# Epoch 250/250
# 3/3 [==============================] - 0s 26ms/step - loss: 0.2813 - accuracy: 0.8403 - val_loss: 0.2392 - val_accuracy: 0.9091
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # prepara salida
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA"
        else:      
            clPred = clases_map[ idclPredRnd ]

        classReal.append( clReal )
        classPreds.append( clPred )

        strTitulo = 'Real: ' + clReal + ' / RNA: ' 
        strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'   
        strTitulo = strTitulo + ": " + ("ok" if (clPred==clReal) else "error!")

        # muestra comparación con la imagen
        print(strTitulo)

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    # agrega para poder mostrar la matrix de confusión completa
    pd.options.display.max_rows = 100
    pd.options.display.max_columns = 100
    print(cmtx)
    print("\n")

    # gráfico de comparación
    plt.title('Gráfico de Confusión:')
    plt.xlabel('Real')
    plt.ylabel('RNA')
    plt.scatter(classReal, classPreds)

# prueba con los datos de entrenamiento
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(matrixTrain, y_train, CLASES)
# Out:
# *** Resultados con datos de Entrenamiento:
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Virginica (3): error!
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Virginica (3): error!
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Virginica (3): error!
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        35
#   Versicolor       1.00      0.91      0.95        34
#    Virginica       0.92      1.00      0.96        35
#
#     accuracy                           0.97       104
#    macro avg       0.97      0.97      0.97       104
# weighted avg       0.97      0.97      0.97       104
#
#
# Matriz de Confusión:
#                p:na  p: Setosa  p: Versicolor  p: Virginica
# r:na              0          0              0             0
# r: Setosa         0         35              0             0
# r: Versicolor     0          0             31             3
# r: Virginica      0          0              0            35

# %% [markdown]
# 6) Evaluar el modelo de la RNA entrenado con los datos de prueba:

# %%
 #@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(matrixTest, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de prueba
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(matrixTest, y_test, CLASES)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
#
# >Evaluación del Modelo:
#     - Error:  0.0028257626108825207
#     - Exactitud:  100.0
#
#
#
#
# *** Resultados con datos de Prueba:
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Virginica / RNA:  Virginica (3): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Setosa / RNA:  Setosa (1): ok
# Real:  Versicolor / RNA:  Versicolor (2): ok
# Real:  Virginica / RNA:  Virginica (3): ok
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        15
#   Versicolor       1.00      1.00      1.00        16
#    Virginica       1.00      1.00      1.00        15
#
#     accuracy                           1.00        46
#    macro avg       1.00      1.00      1.00        46
# weighted avg       1.00      1.00      1.00        46
#
#
# Matriz de Confusión:
#                p:na  p: Setosa  p: Versicolor  p: Virginica
# r:na              0          0              0             0
# r: Setosa         0         15              0             0
# r: Versicolor     0          0             16             0
# r: Virginica      0          0              0            15
