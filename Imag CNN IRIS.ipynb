# %% [markdown]
# # Demo Convolutional Neural Network (CNN) para procesar imágenes e identificar TIPOS de Flores IRIS

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
import keras
from keras.layers import Input, Dense
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Reshape, Flatten, Dropout
from keras.models import Model
from keras.utils import plot_model

from sklearn.model_selection import train_test_split
from keras.utils import np_utils

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho =  64#@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}
imagen_usar_generadas_data_augmentation = True #@param {type:"boolean"}

#@markdown ### Parámetros de la red:
cnn_tamaño_kernel =  2#@param {type:"integer"}
cnn_tamaño_pooling = 2 #@param {type:"integer"}
cnn_cantidad_capas_ocultas =  5#@param {type:"integer"}
cnn_cantidad_neuronas_Dense =  "16,8" #@param {type:"string"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento =  200#@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# indica si se usan las imágenes generadas por data augmentation
usarDA = imagen_usar_generadas_data_augmentation

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel, cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling, cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
#cnn_filters = [ 128, 64, 32, 16, 8 ] 
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = []
for val in cnn_cantidad_neuronas_Dense.split(","):
  num_Dense_out.append( int(val) )
if len(num_Dense_out)<1:
   num_Dense_out.append( 8 )
#num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Tamaño Imagen: ", IMAGE_SHAPE)
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", IMAGE_SHAPE, ", Conv", cnn_filters,  ", FLATTEN, Dense[", num_Dense_out, "], ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Tamaño Imagen:  (64, 64, 3)
#      -Kernels + Pooling: [ (2, 2) + (2, 2) ]
#      -Capas: [  (64, 64, 3) , Conv [128, 64, 32, 16, 8] , FLATTEN, Dense[ [16, 8] ],  Softmax

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demo IRIS/imagenes' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
#@title Cargar imágenes
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            if usarDA or (not esImagDA): 
                
                # abre la imagen
                imag = Image.open(auxiPath + "/" + each_imagFN)
                
                # ajusta el tamaño
                if IMAGE_SHAPE[2]==1:              
                  tipoImage = 'L'
                else:                
                  tipoImage = 'RGB'
                imag = imag.convert(tipoImage)
                imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
                
                # transforma a un vector de nros
                arImag = np.array(imag)
                
                # agrega a los vectores
                classes_ori.append( each_dir )
                images_ori.append( arImag )
                esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  24
# - Imágenes cargadas:  24
# - Ejemplo  versicolor   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FE8713DEA10>
# > Para Prueba:
# - Clases cargadas:  9
# - Imágenes cargadas:  9
# - Ejemplo  setosa   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FE8713EF590>

# %%
#@title Preparar imágenes
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), IMAGE_SHAPE[0], IMAGE_SHAPE[1], IMAGE_SHAPE[2]))  
  return auxiAr
  
# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = np_utils.to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
if tipo_output_softMax:
  print(" - y_trainEnc (cant): ", len(y_trainEnc))
else:
  print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if tipo_output_softMax:
  print(" - y_testEnc (cant): ", len(y_testEnc))
else:
  print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (24, 64, 64, 3)
#  - y_trainEnc (cant):  24
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (9, 64, 64, 3)
#  - y_testEnc (cant):  9
#
#
# > Para Ambos:
#  - dictMapeo:  {'versicolor': 0, 'virginica': 1, 'setosa': 2}
#  - clases_map:  ['versicolor', 'virginica', 'setosa']
#
#  - Imagen reconstruida de  versicolor ( 0  /  [1. 0. 0.] )

# %% [markdown]
# 5) Establecer el modelo para la CNN:

# %%
#@title Establecer modelo

# define la arquitectura de capas de la CNN
# teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=IMAGE_SHAPE, name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'conv_'
for i in range(len(cnn_filters)):  

    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(i+1)

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv2D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling2D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
iDense = 1
for cantDense in num_Dense_out:
  eachLay = Dense(cantDense, activation='relu', name='d_'+auxlayerName+str(iDense))(eachLay)
  iDense = iDense + 1

#eachLay = Dropout(0.5)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo Deep Autoencoder
model = Model(input_img_Lay, output_img_Lay, name='ConvNet')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo CNN creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo CNN creado con  15  capas:
# Model: "ConvNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 64, 64, 3)]       0
# _________________________________________________________________
# c_conv_1 (Conv2D)            (None, 64, 64, 128)       1664
# _________________________________________________________________
# p_conv_1 (MaxPooling2D)      (None, 32, 32, 128)       0
# _________________________________________________________________
# c_conv_2 (Conv2D)            (None, 32, 32, 64)        32832
# _________________________________________________________________
# p_conv_2 (MaxPooling2D)      (None, 16, 16, 64)        0
# _________________________________________________________________
# c_conv_3 (Conv2D)            (None, 16, 16, 32)        8224
# _________________________________________________________________
# p_conv_3 (MaxPooling2D)      (None, 8, 8, 32)          0
# _________________________________________________________________
# c_conv_4 (Conv2D)            (None, 8, 8, 16)          2064
# _________________________________________________________________
# p_conv_4 (MaxPooling2D)      (None, 4, 4, 16)          0
# _________________________________________________________________
# c_conv_5 (Conv2D)            (None, 4, 4, 8)           520
# _________________________________________________________________
# p_conv_5 (MaxPooling2D)      (None, 2, 2, 8)           0
# _________________________________________________________________
# flat_conv_5 (Flatten)        (None, 32)                0
# _________________________________________________________________
# d_conv_51 (Dense)            (None, 16)                528
# _________________________________________________________________
# d_conv_52 (Dense)            (None, 8)                 136
# _________________________________________________________________
# output (Dense)               (None, 3)                 27
# =================================================================
# Total params: 45,995
# Trainable params: 45,995
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,),
          callbacks=[] ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  24 ejemplos de entrenamiento:
#             se usan  21 ejemplos para entrenar
#             y  3 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/200
# 1/1 [==============================] - 4s 4s/step - loss: 1.1014 - accuracy: 0.2857 - val_loss: 1.0879 - val_accuracy: 0.6667
# Epoch 2/200
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0991 - accuracy: 0.2857 - val_loss: 1.0942 - val_accuracy: 0.6667
# Epoch 3/200
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0964 - accuracy: 0.3810 - val_loss: 1.1056 - val_accuracy: 0.3333
# Epoch 4/200
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0946 - accuracy: 0.4286 - val_loss: 1.1030 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0906 - accuracy: 0.5714 - val_loss: 1.0899 - val_accuracy: 0.6667
# Epoch 6/200
# 1/1 [==============================] - 0s 43ms/step - loss: 1.0888 - accuracy: 0.4286 - val_loss: 1.0867 - val_accuracy: 0.6667
# Epoch 7/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0857 - accuracy: 0.4286 - val_loss: 1.0921 - val_accuracy: 0.6667
# Epoch 8/200
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0817 - accuracy: 0.5714 - val_loss: 1.0992 - val_accuracy: 0.3333
# Epoch 9/200
# 1/1 [==============================] - 0s 44ms/step - loss: 1.0777 - accuracy: 0.6667 - val_loss: 1.1051 - val_accuracy: 0.3333
# Epoch 10/200
# 1/1 [==============================] - 0s 40ms/step - loss: 1.0744 - accuracy: 0.8095 - val_loss: 1.1050 - val_accuracy: 0.3333
# Epoch 11/200
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0694 - accuracy: 0.8095 - val_loss: 1.0981 - val_accuracy: 0.3333
# Epoch 12/200
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0640 - accuracy: 0.6667 - val_loss: 1.0921 - val_accuracy: 0.3333
# Epoch 13/200
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0584 - accuracy: 0.7143 - val_loss: 1.0914 - val_accuracy: 0.3333
# Epoch 14/200
# 1/1 [==============================] - 0s 42ms/step - loss: 1.0517 - accuracy: 0.7143 - val_loss: 1.0977 - val_accuracy: 0.3333
# Epoch 15/200
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0443 - accuracy: 0.7143 - val_loss: 1.1004 - val_accuracy: 0.3333
# Epoch 16/200
# 1/1 [==============================] - 0s 37ms/step - loss: 1.0354 - accuracy: 0.7143 - val_loss: 1.0993 - val_accuracy: 0.3333
# Epoch 17/200
# 1/1 [==============================] - 0s 39ms/step - loss: 1.0250 - accuracy: 0.7619 - val_loss: 1.1041 - val_accuracy: 0.3333
# Epoch 18/200
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0130 - accuracy: 0.7619 - val_loss: 1.1204 - val_accuracy: 0.3333
# Epoch 19/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9993 - accuracy: 0.8095 - val_loss: 1.1342 - val_accuracy: 0.0000e+00
# Epoch 20/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.9838 - accuracy: 0.8095 - val_loss: 1.1458 - val_accuracy: 0.0000e+00
# Epoch 21/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.9654 - accuracy: 0.8095 - val_loss: 1.1573 - val_accuracy: 0.0000e+00
# Epoch 22/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.9443 - accuracy: 0.8095 - val_loss: 1.1829 - val_accuracy: 0.0000e+00
# Epoch 23/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.9202 - accuracy: 0.8095 - val_loss: 1.2208 - val_accuracy: 0.0000e+00
# Epoch 24/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8923 - accuracy: 0.8571 - val_loss: 1.2682 - val_accuracy: 0.0000e+00
# Epoch 25/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.8607 - accuracy: 0.9048 - val_loss: 1.3266 - val_accuracy: 0.0000e+00
# Epoch 26/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.8261 - accuracy: 0.8571 - val_loss: 1.4235 - val_accuracy: 0.0000e+00
# Epoch 27/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.7888 - accuracy: 0.9048 - val_loss: 1.5246 - val_accuracy: 0.0000e+00
# Epoch 28/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.7496 - accuracy: 0.8571 - val_loss: 1.6953 - val_accuracy: 0.0000e+00
# Epoch 29/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7092 - accuracy: 0.8571 - val_loss: 1.8481 - val_accuracy: 0.0000e+00
# Epoch 30/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6675 - accuracy: 0.8571 - val_loss: 2.0805 - val_accuracy: 0.0000e+00
# Epoch 31/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6244 - accuracy: 0.8571 - val_loss: 2.2789 - val_accuracy: 0.0000e+00
# Epoch 32/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5827 - accuracy: 0.8571 - val_loss: 2.6478 - val_accuracy: 0.0000e+00
# Epoch 33/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.5403 - accuracy: 0.9524 - val_loss: 2.9058 - val_accuracy: 0.0000e+00
# Epoch 34/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.4994 - accuracy: 0.8571 - val_loss: 3.5172 - val_accuracy: 0.0000e+00
# Epoch 35/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.4574 - accuracy: 0.9524 - val_loss: 3.9437 - val_accuracy: 0.0000e+00
# Epoch 36/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4151 - accuracy: 0.9048 - val_loss: 4.2961 - val_accuracy: 0.0000e+00
# Epoch 37/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3776 - accuracy: 0.9524 - val_loss: 5.4837 - val_accuracy: 0.0000e+00
# Epoch 38/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3450 - accuracy: 0.9048 - val_loss: 5.7818 - val_accuracy: 0.0000e+00
# Epoch 39/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3015 - accuracy: 0.9524 - val_loss: 6.4274 - val_accuracy: 0.0000e+00
# Epoch 40/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2699 - accuracy: 0.9524 - val_loss: 7.8800 - val_accuracy: 0.0000e+00
# Epoch 41/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2394 - accuracy: 0.9524 - val_loss: 8.7468 - val_accuracy: 0.0000e+00
# Epoch 42/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2083 - accuracy: 0.9524 - val_loss: 9.1322 - val_accuracy: 0.0000e+00
# Epoch 43/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1862 - accuracy: 0.9524 - val_loss: 10.5240 - val_accuracy: 0.0000e+00
# Epoch 44/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1584 - accuracy: 0.9524 - val_loss: 12.1792 - val_accuracy: 0.0000e+00
# Epoch 45/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1409 - accuracy: 0.9524 - val_loss: 13.0402 - val_accuracy: 0.0000e+00
# Epoch 46/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.1193 - accuracy: 0.9524 - val_loss: 13.7754 - val_accuracy: 0.0000e+00
# Epoch 47/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1045 - accuracy: 0.9524 - val_loss: 15.3856 - val_accuracy: 0.0000e+00
# Epoch 48/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0883 - accuracy: 0.9524 - val_loss: 17.3590 - val_accuracy: 0.0000e+00
# Epoch 49/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0757 - accuracy: 1.0000 - val_loss: 18.6113 - val_accuracy: 0.0000e+00
# Epoch 50/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0632 - accuracy: 1.0000 - val_loss: 19.2017 - val_accuracy: 0.0000e+00
# Epoch 51/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 20.5246 - val_accuracy: 0.0000e+00
# Epoch 52/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0457 - accuracy: 1.0000 - val_loss: 22.5826 - val_accuracy: 0.0000e+00
# Epoch 53/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 24.3516 - val_accuracy: 0.0000e+00
# Epoch 54/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 25.2039 - val_accuracy: 0.0000e+00
# Epoch 55/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 26.1757 - val_accuracy: 0.0000e+00
# Epoch 56/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 27.8481 - val_accuracy: 0.0000e+00
# Epoch 57/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0170 - accuracy: 1.0000 - val_loss: 29.6543 - val_accuracy: 0.0000e+00
# Epoch 58/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 30.7519 - val_accuracy: 0.0000e+00
# Epoch 59/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 31.5312 - val_accuracy: 0.0000e+00
# Epoch 60/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 32.7006 - val_accuracy: 0.0000e+00
# Epoch 61/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 34.2456 - val_accuracy: 0.0000e+00
# Epoch 62/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 35.6678 - val_accuracy: 0.0000e+00
# Epoch 63/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 36.6329 - val_accuracy: 0.0000e+00
# Epoch 64/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 37.2618 - val_accuracy: 0.0000e+00
# Epoch 65/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 37.8168 - val_accuracy: 0.0000e+00
# Epoch 66/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 38.4892 - val_accuracy: 0.0000e+00
# Epoch 67/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 39.3573 - val_accuracy: 0.0000e+00
# Epoch 68/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 40.3532 - val_accuracy: 0.0000e+00
# Epoch 69/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 41.3606 - val_accuracy: 0.0000e+00
# Epoch 70/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 42.2642 - val_accuracy: 0.0000e+00
# Epoch 71/200
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 43.0209 - val_accuracy: 0.0000e+00
# Epoch 72/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 43.6303 - val_accuracy: 0.0000e+00
# Epoch 73/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 44.1080 - val_accuracy: 0.0000e+00
# Epoch 74/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 44.4520 - val_accuracy: 0.0000e+00
# Epoch 75/200
# 1/1 [==============================] - 0s 44ms/step - loss: 9.0817e-04 - accuracy: 1.0000 - val_loss: 44.7402 - val_accuracy: 0.0000e+00
# Epoch 76/200
# 1/1 [==============================] - 0s 46ms/step - loss: 8.1748e-04 - accuracy: 1.0000 - val_loss: 45.0159 - val_accuracy: 0.0000e+00
# Epoch 77/200
# 1/1 [==============================] - 0s 51ms/step - loss: 7.4610e-04 - accuracy: 1.0000 - val_loss: 45.3020 - val_accuracy: 0.0000e+00
# Epoch 78/200
# 1/1 [==============================] - 0s 46ms/step - loss: 6.8752e-04 - accuracy: 1.0000 - val_loss: 45.6137 - val_accuracy: 0.0000e+00
# Epoch 79/200
# 1/1 [==============================] - 0s 44ms/step - loss: 6.3609e-04 - accuracy: 1.0000 - val_loss: 45.9552 - val_accuracy: 0.0000e+00
# Epoch 80/200
# 1/1 [==============================] - 0s 45ms/step - loss: 5.8836e-04 - accuracy: 1.0000 - val_loss: 46.3228 - val_accuracy: 0.0000e+00
# Epoch 81/200
# 1/1 [==============================] - 0s 45ms/step - loss: 5.4371e-04 - accuracy: 1.0000 - val_loss: 46.7070 - val_accuracy: 0.0000e+00
# Epoch 82/200
# 1/1 [==============================] - 0s 43ms/step - loss: 5.0305e-04 - accuracy: 1.0000 - val_loss: 47.0940 - val_accuracy: 0.0000e+00
# Epoch 83/200
# 1/1 [==============================] - 0s 45ms/step - loss: 4.6779e-04 - accuracy: 1.0000 - val_loss: 47.4702 - val_accuracy: 0.0000e+00
# Epoch 84/200
# 1/1 [==============================] - 0s 45ms/step - loss: 4.3828e-04 - accuracy: 1.0000 - val_loss: 47.8215 - val_accuracy: 0.0000e+00
# Epoch 85/200
# 1/1 [==============================] - 0s 49ms/step - loss: 4.1394e-04 - accuracy: 1.0000 - val_loss: 48.1364 - val_accuracy: 0.0000e+00
# Epoch 86/200
# 1/1 [==============================] - 0s 45ms/step - loss: 3.9356e-04 - accuracy: 1.0000 - val_loss: 48.4072 - val_accuracy: 0.0000e+00
# Epoch 87/200
# 1/1 [==============================] - 0s 47ms/step - loss: 3.7562e-04 - accuracy: 1.0000 - val_loss: 48.6313 - val_accuracy: 0.0000e+00
# Epoch 88/200
# 1/1 [==============================] - 0s 45ms/step - loss: 3.5894e-04 - accuracy: 1.0000 - val_loss: 48.8100 - val_accuracy: 0.0000e+00
# Epoch 89/200
# 1/1 [==============================] - 0s 44ms/step - loss: 3.4309e-04 - accuracy: 1.0000 - val_loss: 48.9497 - val_accuracy: 0.0000e+00
# Epoch 90/200
# 1/1 [==============================] - 0s 47ms/step - loss: 3.2823e-04 - accuracy: 1.0000 - val_loss: 49.0597 - val_accuracy: 0.0000e+00
# Epoch 91/200
# 1/1 [==============================] - 0s 50ms/step - loss: 3.1450e-04 - accuracy: 1.0000 - val_loss: 49.1494 - val_accuracy: 0.0000e+00
# Epoch 92/200
# 1/1 [==============================] - 0s 46ms/step - loss: 3.0233e-04 - accuracy: 1.0000 - val_loss: 49.2283 - val_accuracy: 0.0000e+00
# Epoch 93/200
# 1/1 [==============================] - 0s 43ms/step - loss: 2.9167e-04 - accuracy: 1.0000 - val_loss: 49.3051 - val_accuracy: 0.0000e+00
# Epoch 94/200
# 1/1 [==============================] - 0s 43ms/step - loss: 2.8239e-04 - accuracy: 1.0000 - val_loss: 49.3864 - val_accuracy: 0.0000e+00
# Epoch 95/200
# 1/1 [==============================] - 0s 44ms/step - loss: 2.7409e-04 - accuracy: 1.0000 - val_loss: 49.4770 - val_accuracy: 0.0000e+00
# Epoch 96/200
# 1/1 [==============================] - 0s 45ms/step - loss: 2.6637e-04 - accuracy: 1.0000 - val_loss: 49.5794 - val_accuracy: 0.0000e+00
# Epoch 97/200
# 1/1 [==============================] - 0s 45ms/step - loss: 2.5902e-04 - accuracy: 1.0000 - val_loss: 49.6935 - val_accuracy: 0.0000e+00
# Epoch 98/200
# 1/1 [==============================] - 0s 47ms/step - loss: 2.5194e-04 - accuracy: 1.0000 - val_loss: 49.8177 - val_accuracy: 0.0000e+00
# Epoch 99/200
# 1/1 [==============================] - 0s 46ms/step - loss: 2.4521e-04 - accuracy: 1.0000 - val_loss: 49.9485 - val_accuracy: 0.0000e+00
# Epoch 100/200
# 1/1 [==============================] - 0s 44ms/step - loss: 2.3879e-04 - accuracy: 1.0000 - val_loss: 50.0818 - val_accuracy: 0.0000e+00
# Epoch 101/200
# 1/1 [==============================] - 0s 45ms/step - loss: 2.3279e-04 - accuracy: 1.0000 - val_loss: 50.2131 - val_accuracy: 0.0000e+00
# Epoch 102/200
# 1/1 [==============================] - 0s 43ms/step - loss: 2.2737e-04 - accuracy: 1.0000 - val_loss: 50.3386 - val_accuracy: 0.0000e+00
# Epoch 103/200
# 1/1 [==============================] - 0s 45ms/step - loss: 2.2250e-04 - accuracy: 1.0000 - val_loss: 50.4545 - val_accuracy: 0.0000e+00
# Epoch 104/200
# 1/1 [==============================] - 0s 47ms/step - loss: 2.1803e-04 - accuracy: 1.0000 - val_loss: 50.5582 - val_accuracy: 0.0000e+00
# Epoch 105/200
# 1/1 [==============================] - 0s 50ms/step - loss: 2.1396e-04 - accuracy: 1.0000 - val_loss: 50.6479 - val_accuracy: 0.0000e+00
# Epoch 106/200
# 1/1 [==============================] - 0s 45ms/step - loss: 2.1012e-04 - accuracy: 1.0000 - val_loss: 50.7235 - val_accuracy: 0.0000e+00
# Epoch 107/200
# 1/1 [==============================] - 0s 47ms/step - loss: 2.0643e-04 - accuracy: 1.0000 - val_loss: 50.7864 - val_accuracy: 0.0000e+00
# Epoch 108/200
# 1/1 [==============================] - 0s 45ms/step - loss: 2.0285e-04 - accuracy: 1.0000 - val_loss: 50.8374 - val_accuracy: 0.0000e+00
# Epoch 109/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.9941e-04 - accuracy: 1.0000 - val_loss: 50.8791 - val_accuracy: 0.0000e+00
# Epoch 110/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.9614e-04 - accuracy: 1.0000 - val_loss: 50.9154 - val_accuracy: 0.0000e+00
# Epoch 111/200
# 1/1 [==============================] - 0s 51ms/step - loss: 1.9302e-04 - accuracy: 1.0000 - val_loss: 50.9482 - val_accuracy: 0.0000e+00
# Epoch 112/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.9011e-04 - accuracy: 1.0000 - val_loss: 50.9802 - val_accuracy: 0.0000e+00
# Epoch 113/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.8746e-04 - accuracy: 1.0000 - val_loss: 51.0144 - val_accuracy: 0.0000e+00
# Epoch 114/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.8501e-04 - accuracy: 1.0000 - val_loss: 51.0528 - val_accuracy: 0.0000e+00
# Epoch 115/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.8270e-04 - accuracy: 1.0000 - val_loss: 51.0966 - val_accuracy: 0.0000e+00
# Epoch 116/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.8046e-04 - accuracy: 1.0000 - val_loss: 51.1462 - val_accuracy: 0.0000e+00
# Epoch 117/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.7828e-04 - accuracy: 1.0000 - val_loss: 51.2011 - val_accuracy: 0.0000e+00
# Epoch 118/200
# 1/1 [==============================] - 0s 44ms/step - loss: 1.7608e-04 - accuracy: 1.0000 - val_loss: 51.2607 - val_accuracy: 0.0000e+00
# Epoch 119/200
# 1/1 [==============================] - 0s 44ms/step - loss: 1.7397e-04 - accuracy: 1.0000 - val_loss: 51.3237 - val_accuracy: 0.0000e+00
# Epoch 120/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.7188e-04 - accuracy: 1.0000 - val_loss: 51.3883 - val_accuracy: 0.0000e+00
# Epoch 121/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.6989e-04 - accuracy: 1.0000 - val_loss: 51.4531 - val_accuracy: 0.0000e+00
# Epoch 122/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.6799e-04 - accuracy: 1.0000 - val_loss: 51.5163 - val_accuracy: 0.0000e+00
# Epoch 123/200
# 1/1 [==============================] - 0s 44ms/step - loss: 1.6615e-04 - accuracy: 1.0000 - val_loss: 51.5766 - val_accuracy: 0.0000e+00
# Epoch 124/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.6440e-04 - accuracy: 1.0000 - val_loss: 51.6330 - val_accuracy: 0.0000e+00
# Epoch 125/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.6269e-04 - accuracy: 1.0000 - val_loss: 51.6846 - val_accuracy: 0.0000e+00
# Epoch 126/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.6100e-04 - accuracy: 1.0000 - val_loss: 51.7304 - val_accuracy: 0.0000e+00
# Epoch 127/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5928e-04 - accuracy: 1.0000 - val_loss: 51.7704 - val_accuracy: 0.0000e+00
# Epoch 128/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.5761e-04 - accuracy: 1.0000 - val_loss: 51.8051 - val_accuracy: 0.0000e+00
# Epoch 129/200
# 1/1 [==============================] - 0s 44ms/step - loss: 1.5596e-04 - accuracy: 1.0000 - val_loss: 51.8356 - val_accuracy: 0.0000e+00
# Epoch 130/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.5433e-04 - accuracy: 1.0000 - val_loss: 51.8624 - val_accuracy: 0.0000e+00
# Epoch 131/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.5273e-04 - accuracy: 1.0000 - val_loss: 51.8867 - val_accuracy: 0.0000e+00
# Epoch 132/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.5117e-04 - accuracy: 1.0000 - val_loss: 51.9097 - val_accuracy: 0.0000e+00
# Epoch 133/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.4963e-04 - accuracy: 1.0000 - val_loss: 51.9324 - val_accuracy: 0.0000e+00
# Epoch 134/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.4815e-04 - accuracy: 1.0000 - val_loss: 51.9557 - val_accuracy: 0.0000e+00
# Epoch 135/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.4668e-04 - accuracy: 1.0000 - val_loss: 51.9803 - val_accuracy: 0.0000e+00
# Epoch 136/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.4523e-04 - accuracy: 1.0000 - val_loss: 52.0066 - val_accuracy: 0.0000e+00
# Epoch 137/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.4381e-04 - accuracy: 1.0000 - val_loss: 52.0348 - val_accuracy: 0.0000e+00
# Epoch 138/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.4242e-04 - accuracy: 1.0000 - val_loss: 52.0652 - val_accuracy: 0.0000e+00
# Epoch 139/200
# 1/1 [==============================] - 0s 49ms/step - loss: 1.4104e-04 - accuracy: 1.0000 - val_loss: 52.0971 - val_accuracy: 0.0000e+00
# Epoch 140/200
# 1/1 [==============================] - 0s 51ms/step - loss: 1.3970e-04 - accuracy: 1.0000 - val_loss: 52.1304 - val_accuracy: 0.0000e+00
# Epoch 141/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.3837e-04 - accuracy: 1.0000 - val_loss: 52.1645 - val_accuracy: 0.0000e+00
# Epoch 142/200
# 1/1 [==============================] - 0s 51ms/step - loss: 1.3706e-04 - accuracy: 1.0000 - val_loss: 52.1993 - val_accuracy: 0.0000e+00
# Epoch 143/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3579e-04 - accuracy: 1.0000 - val_loss: 52.2339 - val_accuracy: 0.0000e+00
# Epoch 144/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3453e-04 - accuracy: 1.0000 - val_loss: 52.2681 - val_accuracy: 0.0000e+00
# Epoch 145/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.3329e-04 - accuracy: 1.0000 - val_loss: 52.3015 - val_accuracy: 0.0000e+00
# Epoch 146/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3207e-04 - accuracy: 1.0000 - val_loss: 52.3339 - val_accuracy: 0.0000e+00
# Epoch 147/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.3085e-04 - accuracy: 1.0000 - val_loss: 52.3648 - val_accuracy: 0.0000e+00
# Epoch 148/200
# 1/1 [==============================] - 0s 53ms/step - loss: 1.2968e-04 - accuracy: 1.0000 - val_loss: 52.3944 - val_accuracy: 0.0000e+00
# Epoch 149/200
# 1/1 [==============================] - 0s 56ms/step - loss: 1.2851e-04 - accuracy: 1.0000 - val_loss: 52.4227 - val_accuracy: 0.0000e+00
# Epoch 150/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.2736e-04 - accuracy: 1.0000 - val_loss: 52.4497 - val_accuracy: 0.0000e+00
# Epoch 151/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2623e-04 - accuracy: 1.0000 - val_loss: 52.4756 - val_accuracy: 0.0000e+00
# Epoch 152/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2512e-04 - accuracy: 1.0000 - val_loss: 52.5006 - val_accuracy: 0.0000e+00
# Epoch 153/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2402e-04 - accuracy: 1.0000 - val_loss: 52.5251 - val_accuracy: 0.0000e+00
# Epoch 154/200
# 1/1 [==============================] - 0s 51ms/step - loss: 1.2293e-04 - accuracy: 1.0000 - val_loss: 52.5492 - val_accuracy: 0.0000e+00
# Epoch 155/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2186e-04 - accuracy: 1.0000 - val_loss: 52.5734 - val_accuracy: 0.0000e+00
# Epoch 156/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.2081e-04 - accuracy: 1.0000 - val_loss: 52.5977 - val_accuracy: 0.0000e+00
# Epoch 157/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.1977e-04 - accuracy: 1.0000 - val_loss: 52.6222 - val_accuracy: 0.0000e+00
# Epoch 158/200
# 1/1 [==============================] - 0s 49ms/step - loss: 1.1872e-04 - accuracy: 1.0000 - val_loss: 52.6469 - val_accuracy: 0.0000e+00
# Epoch 159/200
# 1/1 [==============================] - 0s 51ms/step - loss: 1.1772e-04 - accuracy: 1.0000 - val_loss: 52.6727 - val_accuracy: 0.0000e+00
# Epoch 160/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.1674e-04 - accuracy: 1.0000 - val_loss: 52.6993 - val_accuracy: 0.0000e+00
# Epoch 161/200
# 1/1 [==============================] - 0s 52ms/step - loss: 1.1580e-04 - accuracy: 1.0000 - val_loss: 52.7267 - val_accuracy: 0.0000e+00
# Epoch 162/200
# 1/1 [==============================] - 0s 63ms/step - loss: 1.1486e-04 - accuracy: 1.0000 - val_loss: 52.7544 - val_accuracy: 0.0000e+00
# Epoch 163/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.1392e-04 - accuracy: 1.0000 - val_loss: 52.7825 - val_accuracy: 0.0000e+00
# Epoch 164/200
# 1/1 [==============================] - 0s 46ms/step - loss: 1.1300e-04 - accuracy: 1.0000 - val_loss: 52.8107 - val_accuracy: 0.0000e+00
# Epoch 165/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.1212e-04 - accuracy: 1.0000 - val_loss: 52.8391 - val_accuracy: 0.0000e+00
# Epoch 166/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.1122e-04 - accuracy: 1.0000 - val_loss: 52.8677 - val_accuracy: 0.0000e+00
# Epoch 167/200
# 1/1 [==============================] - 0s 51ms/step - loss: 1.1031e-04 - accuracy: 1.0000 - val_loss: 52.8963 - val_accuracy: 0.0000e+00
# Epoch 168/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0944e-04 - accuracy: 1.0000 - val_loss: 52.9249 - val_accuracy: 0.0000e+00
# Epoch 169/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0856e-04 - accuracy: 1.0000 - val_loss: 52.9536 - val_accuracy: 0.0000e+00
# Epoch 170/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0770e-04 - accuracy: 1.0000 - val_loss: 52.9821 - val_accuracy: 0.0000e+00
# Epoch 171/200
# 1/1 [==============================] - 0s 48ms/step - loss: 1.0684e-04 - accuracy: 1.0000 - val_loss: 53.0106 - val_accuracy: 0.0000e+00
# Epoch 172/200
# 1/1 [==============================] - 0s 50ms/step - loss: 1.0601e-04 - accuracy: 1.0000 - val_loss: 53.0392 - val_accuracy: 0.0000e+00
# Epoch 173/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0519e-04 - accuracy: 1.0000 - val_loss: 53.0681 - val_accuracy: 0.0000e+00
# Epoch 174/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0415e-04 - accuracy: 1.0000 - val_loss: 53.1092 - val_accuracy: 0.0000e+00
# Epoch 175/200
# 1/1 [==============================] - 0s 47ms/step - loss: 1.0249e-04 - accuracy: 1.0000 - val_loss: 53.1601 - val_accuracy: 0.0000e+00
# Epoch 176/200
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0044e-04 - accuracy: 1.0000 - val_loss: 53.2176 - val_accuracy: 0.0000e+00
# Epoch 177/200
# 1/1 [==============================] - 0s 47ms/step - loss: 9.8174e-05 - accuracy: 1.0000 - val_loss: 53.2784 - val_accuracy: 0.0000e+00
# Epoch 178/200
# 1/1 [==============================] - 0s 47ms/step - loss: 9.5825e-05 - accuracy: 1.0000 - val_loss: 53.3392 - val_accuracy: 0.0000e+00
# Epoch 179/200
# 1/1 [==============================] - 0s 48ms/step - loss: 9.3482e-05 - accuracy: 1.0000 - val_loss: 53.3982 - val_accuracy: 0.0000e+00
# Epoch 180/200
# 1/1 [==============================] - 0s 44ms/step - loss: 9.1229e-05 - accuracy: 1.0000 - val_loss: 53.4518 - val_accuracy: 0.0000e+00
# Epoch 181/200
# 1/1 [==============================] - 0s 48ms/step - loss: 8.9885e-05 - accuracy: 1.0000 - val_loss: 53.4874 - val_accuracy: 0.0000e+00
# Epoch 182/200
# 1/1 [==============================] - 0s 47ms/step - loss: 8.9493e-05 - accuracy: 1.0000 - val_loss: 53.5051 - val_accuracy: 0.0000e+00
# Epoch 183/200
# 1/1 [==============================] - 0s 47ms/step - loss: 8.8925e-05 - accuracy: 1.0000 - val_loss: 53.5037 - val_accuracy: 0.0000e+00
# Epoch 184/200
# 1/1 [==============================] - 0s 46ms/step - loss: 8.8136e-05 - accuracy: 1.0000 - val_loss: 53.4888 - val_accuracy: 0.0000e+00
# Epoch 185/200
# 1/1 [==============================] - 0s 45ms/step - loss: 8.7098e-05 - accuracy: 1.0000 - val_loss: 53.4646 - val_accuracy: 0.0000e+00
# Epoch 186/200
# 1/1 [==============================] - 0s 57ms/step - loss: 8.5924e-05 - accuracy: 1.0000 - val_loss: 53.4354 - val_accuracy: 0.0000e+00
# Epoch 187/200
# 1/1 [==============================] - 0s 58ms/step - loss: 8.4658e-05 - accuracy: 1.0000 - val_loss: 53.4057 - val_accuracy: 0.0000e+00
# Epoch 188/200
# 1/1 [==============================] - 0s 53ms/step - loss: 8.3433e-05 - accuracy: 1.0000 - val_loss: 53.3784 - val_accuracy: 0.0000e+00
# Epoch 189/200
# 1/1 [==============================] - 0s 55ms/step - loss: 8.2258e-05 - accuracy: 1.0000 - val_loss: 53.3562 - val_accuracy: 0.0000e+00
# Epoch 190/200
# 1/1 [==============================] - 0s 47ms/step - loss: 8.1214e-05 - accuracy: 1.0000 - val_loss: 53.3392 - val_accuracy: 0.0000e+00
# Epoch 191/200
# 1/1 [==============================] - 0s 45ms/step - loss: 8.0193e-05 - accuracy: 1.0000 - val_loss: 53.3310 - val_accuracy: 0.0000e+00
# Epoch 192/200
# 1/1 [==============================] - 0s 45ms/step - loss: 7.9239e-05 - accuracy: 1.0000 - val_loss: 53.3326 - val_accuracy: 0.0000e+00
# Epoch 193/200
# 1/1 [==============================] - 0s 47ms/step - loss: 7.8314e-05 - accuracy: 1.0000 - val_loss: 53.3439 - val_accuracy: 0.0000e+00
# Epoch 194/200
# 1/1 [==============================] - 0s 47ms/step - loss: 7.7401e-05 - accuracy: 1.0000 - val_loss: 53.3644 - val_accuracy: 0.0000e+00
# Epoch 195/200
# 1/1 [==============================] - 0s 46ms/step - loss: 7.6487e-05 - accuracy: 1.0000 - val_loss: 53.3927 - val_accuracy: 0.0000e+00
# Epoch 196/200
# 1/1 [==============================] - 0s 46ms/step - loss: 7.5596e-05 - accuracy: 1.0000 - val_loss: 53.4270 - val_accuracy: 0.0000e+00
# Epoch 197/200
# 1/1 [==============================] - 0s 49ms/step - loss: 7.4734e-05 - accuracy: 1.0000 - val_loss: 53.4652 - val_accuracy: 0.0000e+00
# Epoch 198/200
# 1/1 [==============================] - 0s 45ms/step - loss: 7.3922e-05 - accuracy: 1.0000 - val_loss: 53.5051 - val_accuracy: 0.0000e+00
# Epoch 199/200
# 1/1 [==============================] - 0s 46ms/step - loss: 7.3150e-05 - accuracy: 1.0000 - val_loss: 53.5445 - val_accuracy: 0.0000e+00
# Epoch 200/200
# 1/1 [==============================] - 0s 48ms/step - loss: 7.2418e-05 - accuracy: 1.0000 - val_loss: 53.5816 - val_accuracy: 0.0000e+00
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, esDAimag, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )

        # sólo muestra las imágenes no generadas por DA
        if not esDAimag[i]:
          strTitulo = 'Real: ' + clReal + ' / RNA: ' 
          strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

          # muestra comparación con la imagen
          fig = plt.figure()
          fig.suptitle( strTitulo )
          ax1 = fig.add_subplot(121)
          plot_image( x[i] )
          
          plt.tight_layout()
          fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, esDAimag_train, clases_map)
# Out:
# *** Resultados con datos de Entrenamiento:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       setosa       0.78      0.88      0.82         8
#   versicolor       0.89      1.00      0.94         8
#    virginica       1.00      0.75      0.86         8
#
#     accuracy                           0.88        24
#    macro avg       0.89      0.88      0.87        24
# weighted avg       0.89      0.88      0.87        24
#
#
# Matriz de Confusión:
#               p:versicolor  p:virginica  p:setosa
# r:versicolor             8            0         0
# r:virginica              0            6         2
# r:setosa                 1            0         7
#
#
#
# >Resultados:

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
#@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, esDAimag_test, clases_map)
# Out:
# 1/1 [==============================] - 0s 111ms/step - loss: 9.1306 - accuracy: 0.7778
#
# >Evaluación del Modelo:
#     - Error:  9.130572319030762
#     - Exactitud:  77.77777910232544
#
#
#
#
# *** Resultados con datos de Prueba:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       setosa       0.67      0.67      0.67         3
#   versicolor       0.75      1.00      0.86         3
#    virginica       1.00      0.67      0.80         3
#
#     accuracy                           0.78         9
#    macro avg       0.81      0.78      0.77         9
# weighted avg       0.81      0.78      0.77         9
#
#
# Matriz de Confusión:
#               p:versicolor  p:virginica  p:setosa
# r:versicolor             3            0         0
# r:virginica              0            2         1
# r:setosa                 1            0         2
#
#
#
# >Resultados:
