# %% [markdown]
# # Demo Convolutional Neural Network (CNN) para procesar imágenes e identificar TIPOS de Flores IRIS

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
import keras
from keras.layers import Input, Dense
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Reshape, Flatten, Dropout
from keras.models import Model
from keras.utils import plot_model

from sklearn.model_selection import train_test_split
from keras.utils import np_utils

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho =  64#@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}
imagen_usar_generadas_data_augmentation = True #@param {type:"boolean"}

#@markdown ### Parámetros de la red:
cnn_tamaño_kernel =  2#@param {type:"integer"}
cnn_tamaño_pooling = 2 #@param {type:"integer"}
cnn_cantidad_capas_ocultas =  5#@param {type:"integer"}
cnn_cantidad_neuronas_Dense =  "32,16,8" #@param {type:"string"}
cnn_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
cnn_cant_epocas_entrenamiento =  200#@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# indica si se usan las imágenes generadas por data augmentation
usarDA = imagen_usar_generadas_data_augmentation

# tamaño de los kernels y pooling (para simplificar son todas iguales)
if cnn_tamaño_kernel<1:
  cnn_tamaño_kernel = 1
cnn_kernel_shape = (cnn_tamaño_kernel, cnn_tamaño_kernel)
if cnn_tamaño_pooling<1:
  cnn_tamaño_pooling=1
cnn_pooling_shape = (cnn_tamaño_pooling, cnn_tamaño_pooling)

# indica la configuración para la parte Encoder 
#   (cada elemento de las listas son la configuración de las capas Conv)
#cnn_filters = [ 128, 64, 32, 16, 8 ] 
if cnn_cantidad_capas_ocultas<1:
  cnn_cantidad_capas_ocultas = 1
cnn_filters = []
for i in range(cnn_cantidad_capas_ocultas, 0, -1):
  cnn_filters.append( 2**(i+2) )

# define tamaño de capa densa previa a la de salida
num_Dense_out = []
for val in cnn_cantidad_neuronas_Dense.split(","):
  num_Dense_out.append( int(val) )
if len(num_Dense_out)<1:
   num_Dense_out.append( 8 )
#num_Dense_out = (8 if cnn_cantidad_neuronas_Dense<1 else cnn_cantidad_neuronas_Dense)

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (cnn_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if cnn_cant_epocas_entrenamiento<1 else cnn_cant_epocas_entrenamiento)

print("Configuración de la CNN definida: ")
print ("     -Tamaño Imagen: ", IMAGE_SHAPE)
print ("     -Kernels + Pooling: [", cnn_kernel_shape, "+", cnn_pooling_shape, "] ")
print ("     -Capas: [ ", IMAGE_SHAPE, ", Conv", cnn_filters,  ", FLATTEN, Dense[", num_Dense_out, "], ", ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Configuración de la CNN definida:
#      -Tamaño Imagen:  (64, 64, 3)
#      -Kernels + Pooling: [ (2, 2) + (2, 2) ]
#      -Capas: [  (64, 64, 3) , Conv [128, 64, 32, 16, 8] , FLATTEN, Dense[ [32, 16, 8] ],  Softmax

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demo IRIS/imagenes' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
#@title Cargar imágenes
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            if usarDA or (not esImagDA): 
                
                # abre la imagen
                imag = Image.open(auxiPath + "/" + each_imagFN)
                
                # ajusta el tamaño
                if IMAGE_SHAPE[2]==1:              
                  tipoImage = 'L'
                else:                
                  tipoImage = 'RGB'
                imag = imag.convert(tipoImage)
                imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
                
                # transforma a un vector de nros
                arImag = np.array(imag)
                
                # agrega a los vectores
                classes_ori.append( each_dir )
                images_ori.append( arImag )
                esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  24
# - Imágenes cargadas:  24
# - Ejemplo  versicolor   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F4768A35AD0>
# > Para Prueba:
# - Clases cargadas:  9
# - Imágenes cargadas:  9
# - Ejemplo  setosa   (64, 64, 3) :
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F4768A35E10>

# %%
#@title Preparar imágenes
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), IMAGE_SHAPE[0], IMAGE_SHAPE[1], IMAGE_SHAPE[2]))  
  return auxiAr
  
# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = np_utils.to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
if tipo_output_softMax:
  print(" - y_trainEnc (cant): ", len(y_trainEnc))
else:
  print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if tipo_output_softMax:
  print(" - y_testEnc (cant): ", len(y_testEnc))
else:
  print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (24, 64, 64, 3)
#  - y_trainEnc (cant):  24
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (9, 64, 64, 3)
#  - y_testEnc (cant):  9
#
#
# > Para Ambos:
#  - dictMapeo:  {'versicolor': 0, 'virginica': 1, 'setosa': 2}
#  - clases_map:  ['versicolor', 'virginica', 'setosa']
#
#  - Imagen reconstruida de  versicolor ( 0  /  [1. 0. 0.] )

# %% [markdown]
# 5) Establecer el modelo para la CNN:

# %%
#@title Establecer modelo

# define la arquitectura de capas de la CNN
# teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=IMAGE_SHAPE, name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'conv_'
for i in range(len(cnn_filters)):  

    # define el nombre de la capa oculta
    auxlayerName = 'conv_'+str(i+1)

    # agrega las capas ocultas de tipo Conv2D + MaxPooling 
    eachLay = Conv2D(cnn_filters[i], cnn_kernel_shape, activation='relu', padding='same', name='c_'+auxlayerName)(eachLay) 
    eachLay = MaxPooling2D(cnn_pooling_shape, padding='same', name='p_'+auxlayerName)(eachLay)

#  agrega capa Flatten y Dense 
eachLay = Flatten(name='flat_'+auxlayerName)(eachLay)
iDense = 1
for cantDense in num_Dense_out:
  eachLay = Dense(cantDense, activation='relu', name='d_'+auxlayerName+str(iDense))(eachLay)
  iDense = iDense + 1

#eachLay = Dropout(0.5)(eachLay)

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida

# genera el modelo Deep Autoencoder
model = Model(input_img_Lay, output_img_Lay, name='ConvNet')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

print("Modelo CNN creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo CNN creado con  16  capas:
# Model: "ConvNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 64, 64, 3)]       0
# _________________________________________________________________
# c_conv_1 (Conv2D)            (None, 64, 64, 128)       1664
# _________________________________________________________________
# p_conv_1 (MaxPooling2D)      (None, 32, 32, 128)       0
# _________________________________________________________________
# c_conv_2 (Conv2D)            (None, 32, 32, 64)        32832
# _________________________________________________________________
# p_conv_2 (MaxPooling2D)      (None, 16, 16, 64)        0
# _________________________________________________________________
# c_conv_3 (Conv2D)            (None, 16, 16, 32)        8224
# _________________________________________________________________
# p_conv_3 (MaxPooling2D)      (None, 8, 8, 32)          0
# _________________________________________________________________
# c_conv_4 (Conv2D)            (None, 8, 8, 16)          2064
# _________________________________________________________________
# p_conv_4 (MaxPooling2D)      (None, 4, 4, 16)          0
# _________________________________________________________________
# c_conv_5 (Conv2D)            (None, 4, 4, 8)           520
# _________________________________________________________________
# p_conv_5 (MaxPooling2D)      (None, 2, 2, 8)           0
# _________________________________________________________________
# flat_conv_5 (Flatten)        (None, 32)                0
# _________________________________________________________________
# d_conv_51 (Dense)            (None, 32)                1056
# _________________________________________________________________
# d_conv_52 (Dense)            (None, 16)                528
# _________________________________________________________________
# d_conv_53 (Dense)            (None, 8)                 136
# _________________________________________________________________
# output (Dense)               (None, 3)                 27
# =================================================================
# Total params: 47,051
# Trainable params: 47,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,)) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  24 ejemplos de entrenamiento:
#             se usan  21 ejemplos para entrenar
#             y  3 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/200
# 1/1 [==============================] - 3s 3s/step - loss: 1.1081 - accuracy: 0.3333 - val_loss: 1.1153 - val_accuracy: 0.3333
# Epoch 2/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.0977 - accuracy: 0.3333 - val_loss: 1.1019 - val_accuracy: 0.3333
# Epoch 3/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0935 - accuracy: 0.3333 - val_loss: 1.1031 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0952 - accuracy: 0.3333 - val_loss: 1.1111 - val_accuracy: 0.3333
# Epoch 5/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.0903 - accuracy: 0.3333 - val_loss: 1.1136 - val_accuracy: 0.3333
# Epoch 6/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.0836 - accuracy: 0.3333 - val_loss: 1.1289 - val_accuracy: 0.3333
# Epoch 7/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0809 - accuracy: 0.3333 - val_loss: 1.1309 - val_accuracy: 0.3333
# Epoch 8/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0750 - accuracy: 0.3333 - val_loss: 1.1263 - val_accuracy: 0.3333
# Epoch 9/200
# 1/1 [==============================] - 0s 54ms/step - loss: 1.0723 - accuracy: 0.3810 - val_loss: 1.1437 - val_accuracy: 0.3333
# Epoch 10/200
# 1/1 [==============================] - 0s 67ms/step - loss: 1.0643 - accuracy: 0.3810 - val_loss: 1.1549 - val_accuracy: 0.3333
# Epoch 11/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.0586 - accuracy: 0.3810 - val_loss: 1.1463 - val_accuracy: 0.3333
# Epoch 12/200
# 1/1 [==============================] - 0s 68ms/step - loss: 1.0509 - accuracy: 0.4286 - val_loss: 1.1528 - val_accuracy: 0.3333
# Epoch 13/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0431 - accuracy: 0.4286 - val_loss: 1.1710 - val_accuracy: 0.3333
# Epoch 14/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.0356 - accuracy: 0.3810 - val_loss: 1.1747 - val_accuracy: 0.3333
# Epoch 15/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0253 - accuracy: 0.4286 - val_loss: 1.1883 - val_accuracy: 0.3333
# Epoch 16/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0150 - accuracy: 0.3810 - val_loss: 1.1818 - val_accuracy: 0.3333
# Epoch 17/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.0042 - accuracy: 0.5238 - val_loss: 1.2110 - val_accuracy: 0.3333
# Epoch 18/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.9920 - accuracy: 0.4762 - val_loss: 1.2267 - val_accuracy: 0.3333
# Epoch 19/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.9776 - accuracy: 0.5238 - val_loss: 1.2433 - val_accuracy: 0.3333
# Epoch 20/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.9630 - accuracy: 0.5238 - val_loss: 1.2700 - val_accuracy: 0.3333
# Epoch 21/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.9486 - accuracy: 0.5238 - val_loss: 1.2813 - val_accuracy: 0.3333
# Epoch 22/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.9304 - accuracy: 0.5238 - val_loss: 1.2862 - val_accuracy: 0.3333
# Epoch 23/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.9150 - accuracy: 0.5238 - val_loss: 1.3683 - val_accuracy: 0.3333
# Epoch 24/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.8969 - accuracy: 0.5238 - val_loss: 1.3792 - val_accuracy: 0.3333
# Epoch 25/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.8735 - accuracy: 0.5238 - val_loss: 1.3446 - val_accuracy: 0.3333
# Epoch 26/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.8557 - accuracy: 0.5714 - val_loss: 1.4163 - val_accuracy: 0.3333
# Epoch 27/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.8305 - accuracy: 0.6190 - val_loss: 1.4786 - val_accuracy: 0.3333
# Epoch 28/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.8088 - accuracy: 0.6190 - val_loss: 1.4760 - val_accuracy: 0.3333
# Epoch 29/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.7807 - accuracy: 0.6667 - val_loss: 1.4556 - val_accuracy: 0.3333
# Epoch 30/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7564 - accuracy: 0.7619 - val_loss: 1.5513 - val_accuracy: 0.3333
# Epoch 31/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.7250 - accuracy: 0.7619 - val_loss: 1.6732 - val_accuracy: 0.3333
# Epoch 32/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7004 - accuracy: 0.7619 - val_loss: 1.6449 - val_accuracy: 0.3333
# Epoch 33/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6725 - accuracy: 0.8095 - val_loss: 1.6458 - val_accuracy: 0.3333
# Epoch 34/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6457 - accuracy: 0.8095 - val_loss: 1.7897 - val_accuracy: 0.3333
# Epoch 35/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.6139 - accuracy: 0.8095 - val_loss: 1.9059 - val_accuracy: 0.3333
# Epoch 36/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5882 - accuracy: 0.8095 - val_loss: 1.8879 - val_accuracy: 0.3333
# Epoch 37/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5586 - accuracy: 0.8095 - val_loss: 1.8544 - val_accuracy: 0.3333
# Epoch 38/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.5262 - accuracy: 0.8095 - val_loss: 2.0897 - val_accuracy: 0.3333
# Epoch 39/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4913 - accuracy: 0.8095 - val_loss: 2.2896 - val_accuracy: 0.3333
# Epoch 40/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4570 - accuracy: 0.8095 - val_loss: 2.2376 - val_accuracy: 0.3333
# Epoch 41/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4213 - accuracy: 0.8571 - val_loss: 2.3184 - val_accuracy: 0.3333
# Epoch 42/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3900 - accuracy: 0.9048 - val_loss: 2.6636 - val_accuracy: 0.3333
# Epoch 43/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3597 - accuracy: 0.9048 - val_loss: 2.6486 - val_accuracy: 0.3333
# Epoch 44/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.3268 - accuracy: 1.0000 - val_loss: 2.8138 - val_accuracy: 0.3333
# Epoch 45/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2999 - accuracy: 1.0000 - val_loss: 3.2350 - val_accuracy: 0.3333
# Epoch 46/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2701 - accuracy: 1.0000 - val_loss: 3.2539 - val_accuracy: 0.3333
# Epoch 47/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2415 - accuracy: 1.0000 - val_loss: 3.2841 - val_accuracy: 0.3333
# Epoch 48/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2201 - accuracy: 1.0000 - val_loss: 3.9561 - val_accuracy: 0.3333
# Epoch 49/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1919 - accuracy: 1.0000 - val_loss: 4.2266 - val_accuracy: 0.3333
# Epoch 50/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1710 - accuracy: 1.0000 - val_loss: 3.9241 - val_accuracy: 0.3333
# Epoch 51/200
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1521 - accuracy: 1.0000 - val_loss: 4.5991 - val_accuracy: 0.3333
# Epoch 52/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1270 - accuracy: 1.0000 - val_loss: 5.7461 - val_accuracy: 0.3333
# Epoch 53/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1151 - accuracy: 1.0000 - val_loss: 5.6781 - val_accuracy: 0.3333
# Epoch 54/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0934 - accuracy: 1.0000 - val_loss: 5.5125 - val_accuracy: 0.3333
# Epoch 55/200
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0795 - accuracy: 1.0000 - val_loss: 5.8721 - val_accuracy: 0.3333
# Epoch 56/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0641 - accuracy: 1.0000 - val_loss: 6.6423 - val_accuracy: 0.3333
# Epoch 57/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 7.3855 - val_accuracy: 0.3333
# Epoch 58/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0411 - accuracy: 1.0000 - val_loss: 7.6899 - val_accuracy: 0.3333
# Epoch 59/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 7.9163 - val_accuracy: 0.3333
# Epoch 60/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 8.1361 - val_accuracy: 0.3333
# Epoch 61/200
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 8.2515 - val_accuracy: 0.3333
# Epoch 62/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 8.2965 - val_accuracy: 0.3333
# Epoch 63/200
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 8.2730 - val_accuracy: 0.3333
# Epoch 64/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 8.3100 - val_accuracy: 0.3333
# Epoch 65/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 8.5447 - val_accuracy: 0.3333
# Epoch 66/200
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 9.0156 - val_accuracy: 0.3333
# Epoch 67/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 9.6436 - val_accuracy: 0.3333
# Epoch 68/200
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 10.2363 - val_accuracy: 0.3333
# Epoch 69/200
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 10.7049 - val_accuracy: 0.3333
# Epoch 70/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 11.0384 - val_accuracy: 0.3333
# Epoch 71/200
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 11.2315 - val_accuracy: 0.3333
# Epoch 72/200
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 11.3179 - val_accuracy: 0.3333
# Epoch 73/200
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 11.3372 - val_accuracy: 0.3333
# Epoch 74/200
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 11.3333 - val_accuracy: 0.3333
# Epoch 75/200
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 11.3326 - val_accuracy: 0.3333
# Epoch 76/200
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 11.3512 - val_accuracy: 0.3333
# Epoch 77/200
# 1/1 [==============================] - 0s 60ms/step - loss: 9.3300e-04 - accuracy: 1.0000 - val_loss: 11.4035 - val_accuracy: 0.3333
# Epoch 78/200
# 1/1 [==============================] - 0s 61ms/step - loss: 8.2424e-04 - accuracy: 1.0000 - val_loss: 11.4905 - val_accuracy: 0.3333
# Epoch 79/200
# 1/1 [==============================] - 0s 57ms/step - loss: 7.3485e-04 - accuracy: 1.0000 - val_loss: 11.6072 - val_accuracy: 0.3333
# Epoch 80/200
# 1/1 [==============================] - 0s 63ms/step - loss: 6.6364e-04 - accuracy: 1.0000 - val_loss: 11.7408 - val_accuracy: 0.3333
# Epoch 81/200
# 1/1 [==============================] - 0s 62ms/step - loss: 6.0952e-04 - accuracy: 1.0000 - val_loss: 11.8839 - val_accuracy: 0.3333
# Epoch 82/200
# 1/1 [==============================] - 0s 61ms/step - loss: 5.6453e-04 - accuracy: 1.0000 - val_loss: 12.0300 - val_accuracy: 0.3333
# Epoch 83/200
# 1/1 [==============================] - 0s 57ms/step - loss: 5.2411e-04 - accuracy: 1.0000 - val_loss: 12.1733 - val_accuracy: 0.3333
# Epoch 84/200
# 1/1 [==============================] - 0s 71ms/step - loss: 4.8715e-04 - accuracy: 1.0000 - val_loss: 12.3091 - val_accuracy: 0.3333
# Epoch 85/200
# 1/1 [==============================] - 0s 58ms/step - loss: 4.5282e-04 - accuracy: 1.0000 - val_loss: 12.4372 - val_accuracy: 0.3333
# Epoch 86/200
# 1/1 [==============================] - 0s 59ms/step - loss: 4.2145e-04 - accuracy: 1.0000 - val_loss: 12.5570 - val_accuracy: 0.3333
# Epoch 87/200
# 1/1 [==============================] - 0s 64ms/step - loss: 3.9339e-04 - accuracy: 1.0000 - val_loss: 12.6691 - val_accuracy: 0.3333
# Epoch 88/200
# 1/1 [==============================] - 0s 60ms/step - loss: 3.6961e-04 - accuracy: 1.0000 - val_loss: 12.7746 - val_accuracy: 0.3333
# Epoch 89/200
# 1/1 [==============================] - 0s 63ms/step - loss: 3.4936e-04 - accuracy: 1.0000 - val_loss: 12.8739 - val_accuracy: 0.3333
# Epoch 90/200
# 1/1 [==============================] - 0s 64ms/step - loss: 3.3221e-04 - accuracy: 1.0000 - val_loss: 12.9679 - val_accuracy: 0.3333
# Epoch 91/200
# 1/1 [==============================] - 0s 66ms/step - loss: 3.1770e-04 - accuracy: 1.0000 - val_loss: 13.0553 - val_accuracy: 0.3333
# Epoch 92/200
# 1/1 [==============================] - 0s 72ms/step - loss: 3.0499e-04 - accuracy: 1.0000 - val_loss: 13.1369 - val_accuracy: 0.3333
# Epoch 93/200
# 1/1 [==============================] - 0s 61ms/step - loss: 2.9339e-04 - accuracy: 1.0000 - val_loss: 13.2127 - val_accuracy: 0.3333
# Epoch 94/200
# 1/1 [==============================] - 0s 65ms/step - loss: 2.8269e-04 - accuracy: 1.0000 - val_loss: 13.2805 - val_accuracy: 0.3333
# Epoch 95/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.7296e-04 - accuracy: 1.0000 - val_loss: 13.3404 - val_accuracy: 0.3333
# Epoch 96/200
# 1/1 [==============================] - 0s 62ms/step - loss: 2.6374e-04 - accuracy: 1.0000 - val_loss: 13.3924 - val_accuracy: 0.3333
# Epoch 97/200
# 1/1 [==============================] - 0s 58ms/step - loss: 2.5500e-04 - accuracy: 1.0000 - val_loss: 13.4367 - val_accuracy: 0.3333
# Epoch 98/200
# 1/1 [==============================] - 0s 69ms/step - loss: 2.4684e-04 - accuracy: 1.0000 - val_loss: 13.4747 - val_accuracy: 0.3333
# Epoch 99/200
# 1/1 [==============================] - 0s 63ms/step - loss: 2.3945e-04 - accuracy: 1.0000 - val_loss: 13.5058 - val_accuracy: 0.3333
# Epoch 100/200
# 1/1 [==============================] - 0s 71ms/step - loss: 2.3272e-04 - accuracy: 1.0000 - val_loss: 13.5308 - val_accuracy: 0.3333
# Epoch 101/200
# 1/1 [==============================] - 0s 68ms/step - loss: 2.2667e-04 - accuracy: 1.0000 - val_loss: 13.5495 - val_accuracy: 0.3333
# Epoch 102/200
# 1/1 [==============================] - 0s 65ms/step - loss: 2.2121e-04 - accuracy: 1.0000 - val_loss: 13.5627 - val_accuracy: 0.3333
# Epoch 103/200
# 1/1 [==============================] - 0s 66ms/step - loss: 2.1628e-04 - accuracy: 1.0000 - val_loss: 13.5706 - val_accuracy: 0.3333
# Epoch 104/200
# 1/1 [==============================] - 0s 57ms/step - loss: 2.1179e-04 - accuracy: 1.0000 - val_loss: 13.5741 - val_accuracy: 0.3333
# Epoch 105/200
# 1/1 [==============================] - 0s 64ms/step - loss: 2.0762e-04 - accuracy: 1.0000 - val_loss: 13.5737 - val_accuracy: 0.3333
# Epoch 106/200
# 1/1 [==============================] - 0s 64ms/step - loss: 2.0372e-04 - accuracy: 1.0000 - val_loss: 13.5699 - val_accuracy: 0.3333
# Epoch 107/200
# 1/1 [==============================] - 0s 59ms/step - loss: 2.0002e-04 - accuracy: 1.0000 - val_loss: 13.5636 - val_accuracy: 0.3333
# Epoch 108/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.9655e-04 - accuracy: 1.0000 - val_loss: 13.5573 - val_accuracy: 0.3333
# Epoch 109/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.9325e-04 - accuracy: 1.0000 - val_loss: 13.5517 - val_accuracy: 0.3333
# Epoch 110/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.9011e-04 - accuracy: 1.0000 - val_loss: 13.5474 - val_accuracy: 0.3333
# Epoch 111/200
# 1/1 [==============================] - 0s 64ms/step - loss: 1.8711e-04 - accuracy: 1.0000 - val_loss: 13.5449 - val_accuracy: 0.3333
# Epoch 112/200
# 1/1 [==============================] - 0s 73ms/step - loss: 1.8428e-04 - accuracy: 1.0000 - val_loss: 13.5447 - val_accuracy: 0.3333
# Epoch 113/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.8162e-04 - accuracy: 1.0000 - val_loss: 13.5473 - val_accuracy: 0.3333
# Epoch 114/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7910e-04 - accuracy: 1.0000 - val_loss: 13.5528 - val_accuracy: 0.3333
# Epoch 115/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.7673e-04 - accuracy: 1.0000 - val_loss: 13.5615 - val_accuracy: 0.3333
# Epoch 116/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.7446e-04 - accuracy: 1.0000 - val_loss: 13.5733 - val_accuracy: 0.3333
# Epoch 117/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.7231e-04 - accuracy: 1.0000 - val_loss: 13.5883 - val_accuracy: 0.3333
# Epoch 118/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.7023e-04 - accuracy: 1.0000 - val_loss: 13.6065 - val_accuracy: 0.3333
# Epoch 119/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.6822e-04 - accuracy: 1.0000 - val_loss: 13.6275 - val_accuracy: 0.3333
# Epoch 120/200
# 1/1 [==============================] - 0s 65ms/step - loss: 1.6624e-04 - accuracy: 1.0000 - val_loss: 13.6508 - val_accuracy: 0.3333
# Epoch 121/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.6432e-04 - accuracy: 1.0000 - val_loss: 13.6759 - val_accuracy: 0.3333
# Epoch 122/200
# 1/1 [==============================] - 0s 64ms/step - loss: 1.6247e-04 - accuracy: 1.0000 - val_loss: 13.7036 - val_accuracy: 0.3333
# Epoch 123/200
# 1/1 [==============================] - 0s 63ms/step - loss: 1.6072e-04 - accuracy: 1.0000 - val_loss: 13.7318 - val_accuracy: 0.3333
# Epoch 124/200
# 1/1 [==============================] - 0s 63ms/step - loss: 1.5904e-04 - accuracy: 1.0000 - val_loss: 13.7600 - val_accuracy: 0.3333
# Epoch 125/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.5743e-04 - accuracy: 1.0000 - val_loss: 13.7857 - val_accuracy: 0.3333
# Epoch 126/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.5591e-04 - accuracy: 1.0000 - val_loss: 13.8069 - val_accuracy: 0.3333
# Epoch 127/200
# 1/1 [==============================] - 0s 65ms/step - loss: 1.5445e-04 - accuracy: 1.0000 - val_loss: 13.8235 - val_accuracy: 0.3333
# Epoch 128/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5301e-04 - accuracy: 1.0000 - val_loss: 13.8356 - val_accuracy: 0.3333
# Epoch 129/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.5161e-04 - accuracy: 1.0000 - val_loss: 13.8434 - val_accuracy: 0.3333
# Epoch 130/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.5024e-04 - accuracy: 1.0000 - val_loss: 13.8491 - val_accuracy: 0.3333
# Epoch 131/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.4891e-04 - accuracy: 1.0000 - val_loss: 13.8530 - val_accuracy: 0.3333
# Epoch 132/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.4759e-04 - accuracy: 1.0000 - val_loss: 13.8553 - val_accuracy: 0.3333
# Epoch 133/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.4630e-04 - accuracy: 1.0000 - val_loss: 13.8563 - val_accuracy: 0.3333
# Epoch 134/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.4503e-04 - accuracy: 1.0000 - val_loss: 13.8563 - val_accuracy: 0.3333
# Epoch 135/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.4378e-04 - accuracy: 1.0000 - val_loss: 13.8560 - val_accuracy: 0.3333
# Epoch 136/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.4256e-04 - accuracy: 1.0000 - val_loss: 13.8555 - val_accuracy: 0.3333
# Epoch 137/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.4134e-04 - accuracy: 1.0000 - val_loss: 13.8551 - val_accuracy: 0.3333
# Epoch 138/200
# 1/1 [==============================] - 0s 64ms/step - loss: 1.4016e-04 - accuracy: 1.0000 - val_loss: 13.8564 - val_accuracy: 0.3333
# Epoch 139/200
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3898e-04 - accuracy: 1.0000 - val_loss: 13.8594 - val_accuracy: 0.3333
# Epoch 140/200
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3781e-04 - accuracy: 1.0000 - val_loss: 13.8641 - val_accuracy: 0.3333
# Epoch 141/200
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3668e-04 - accuracy: 1.0000 - val_loss: 13.8700 - val_accuracy: 0.3333
# Epoch 142/200
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3558e-04 - accuracy: 1.0000 - val_loss: 13.8775 - val_accuracy: 0.3333
# Epoch 143/200
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3448e-04 - accuracy: 1.0000 - val_loss: 13.8864 - val_accuracy: 0.3333
# Epoch 144/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3336e-04 - accuracy: 1.0000 - val_loss: 13.8965 - val_accuracy: 0.3333
# Epoch 145/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3230e-04 - accuracy: 1.0000 - val_loss: 13.9076 - val_accuracy: 0.3333
# Epoch 146/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3124e-04 - accuracy: 1.0000 - val_loss: 13.9182 - val_accuracy: 0.3333
# Epoch 147/200
# 1/1 [==============================] - 0s 64ms/step - loss: 1.3019e-04 - accuracy: 1.0000 - val_loss: 13.9280 - val_accuracy: 0.3333
# Epoch 148/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2915e-04 - accuracy: 1.0000 - val_loss: 13.9350 - val_accuracy: 0.3333
# Epoch 149/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2815e-04 - accuracy: 1.0000 - val_loss: 13.9415 - val_accuracy: 0.3333
# Epoch 150/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2714e-04 - accuracy: 1.0000 - val_loss: 13.9475 - val_accuracy: 0.3333
# Epoch 151/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2617e-04 - accuracy: 1.0000 - val_loss: 13.9534 - val_accuracy: 0.3333
# Epoch 152/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2520e-04 - accuracy: 1.0000 - val_loss: 13.9590 - val_accuracy: 0.3333
# Epoch 153/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.2426e-04 - accuracy: 1.0000 - val_loss: 13.9648 - val_accuracy: 0.3333
# Epoch 154/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.2331e-04 - accuracy: 1.0000 - val_loss: 13.9708 - val_accuracy: 0.3333
# Epoch 155/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.2239e-04 - accuracy: 1.0000 - val_loss: 13.9769 - val_accuracy: 0.3333
# Epoch 156/200
# 1/1 [==============================] - 0s 66ms/step - loss: 1.2149e-04 - accuracy: 1.0000 - val_loss: 13.9829 - val_accuracy: 0.3333
# Epoch 157/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.2058e-04 - accuracy: 1.0000 - val_loss: 13.9888 - val_accuracy: 0.3333
# Epoch 158/200
# 1/1 [==============================] - 0s 65ms/step - loss: 1.1973e-04 - accuracy: 1.0000 - val_loss: 13.9961 - val_accuracy: 0.3333
# Epoch 159/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1885e-04 - accuracy: 1.0000 - val_loss: 14.0044 - val_accuracy: 0.3333
# Epoch 160/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1801e-04 - accuracy: 1.0000 - val_loss: 14.0121 - val_accuracy: 0.3333
# Epoch 161/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1720e-04 - accuracy: 1.0000 - val_loss: 14.0174 - val_accuracy: 0.3333
# Epoch 162/200
# 1/1 [==============================] - 0s 61ms/step - loss: 1.1640e-04 - accuracy: 1.0000 - val_loss: 14.0206 - val_accuracy: 0.3333
# Epoch 163/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.1558e-04 - accuracy: 1.0000 - val_loss: 14.0233 - val_accuracy: 0.3333
# Epoch 164/200
# 1/1 [==============================] - 0s 57ms/step - loss: 1.1481e-04 - accuracy: 1.0000 - val_loss: 14.0252 - val_accuracy: 0.3333
# Epoch 165/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.1402e-04 - accuracy: 1.0000 - val_loss: 14.0263 - val_accuracy: 0.3333
# Epoch 166/200
# 1/1 [==============================] - 0s 64ms/step - loss: 1.1325e-04 - accuracy: 1.0000 - val_loss: 14.0281 - val_accuracy: 0.3333
# Epoch 167/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.1247e-04 - accuracy: 1.0000 - val_loss: 14.0314 - val_accuracy: 0.3333
# Epoch 168/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1173e-04 - accuracy: 1.0000 - val_loss: 14.0360 - val_accuracy: 0.3333
# Epoch 169/200
# 1/1 [==============================] - 0s 55ms/step - loss: 1.1097e-04 - accuracy: 1.0000 - val_loss: 14.0419 - val_accuracy: 0.3333
# Epoch 170/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1022e-04 - accuracy: 1.0000 - val_loss: 14.0496 - val_accuracy: 0.3333
# Epoch 171/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.0949e-04 - accuracy: 1.0000 - val_loss: 14.0602 - val_accuracy: 0.3333
# Epoch 172/200
# 1/1 [==============================] - 0s 58ms/step - loss: 1.0877e-04 - accuracy: 1.0000 - val_loss: 14.0716 - val_accuracy: 0.3333
# Epoch 173/200
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0804e-04 - accuracy: 1.0000 - val_loss: 14.0821 - val_accuracy: 0.3333
# Epoch 174/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0732e-04 - accuracy: 1.0000 - val_loss: 14.0914 - val_accuracy: 0.3333
# Epoch 175/200
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0661e-04 - accuracy: 1.0000 - val_loss: 14.1002 - val_accuracy: 0.3333
# Epoch 176/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0592e-04 - accuracy: 1.0000 - val_loss: 14.1077 - val_accuracy: 0.3333
# Epoch 177/200
# 1/1 [==============================] - 0s 63ms/step - loss: 1.0522e-04 - accuracy: 1.0000 - val_loss: 14.1140 - val_accuracy: 0.3333
# Epoch 178/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0455e-04 - accuracy: 1.0000 - val_loss: 14.1191 - val_accuracy: 0.3333
# Epoch 179/200
# 1/1 [==============================] - 0s 60ms/step - loss: 1.0386e-04 - accuracy: 1.0000 - val_loss: 14.1253 - val_accuracy: 0.3333
# Epoch 180/200
# 1/1 [==============================] - 0s 62ms/step - loss: 1.0318e-04 - accuracy: 1.0000 - val_loss: 14.1326 - val_accuracy: 0.3333
# Epoch 181/200
# 1/1 [==============================] - 0s 66ms/step - loss: 1.0253e-04 - accuracy: 1.0000 - val_loss: 14.1391 - val_accuracy: 0.3333
# Epoch 182/200
# 1/1 [==============================] - 0s 59ms/step - loss: 1.0187e-04 - accuracy: 1.0000 - val_loss: 14.1448 - val_accuracy: 0.3333
# Epoch 183/200
# 1/1 [==============================] - 0s 65ms/step - loss: 1.0123e-04 - accuracy: 1.0000 - val_loss: 14.1485 - val_accuracy: 0.3333
# Epoch 184/200
# 1/1 [==============================] - 0s 64ms/step - loss: 1.0059e-04 - accuracy: 1.0000 - val_loss: 14.1513 - val_accuracy: 0.3333
# Epoch 185/200
# 1/1 [==============================] - 0s 70ms/step - loss: 9.9983e-05 - accuracy: 1.0000 - val_loss: 14.1555 - val_accuracy: 0.3333
# Epoch 186/200
# 1/1 [==============================] - 0s 60ms/step - loss: 9.9342e-05 - accuracy: 1.0000 - val_loss: 14.1611 - val_accuracy: 0.3333
# Epoch 187/200
# 1/1 [==============================] - 0s 60ms/step - loss: 9.8723e-05 - accuracy: 1.0000 - val_loss: 14.1678 - val_accuracy: 0.3333
# Epoch 188/200
# 1/1 [==============================] - 0s 60ms/step - loss: 9.8093e-05 - accuracy: 1.0000 - val_loss: 14.1753 - val_accuracy: 0.3333
# Epoch 189/200
# 1/1 [==============================] - 0s 59ms/step - loss: 9.7497e-05 - accuracy: 1.0000 - val_loss: 14.1824 - val_accuracy: 0.3333
# Epoch 190/200
# 1/1 [==============================] - 0s 57ms/step - loss: 9.6907e-05 - accuracy: 1.0000 - val_loss: 14.1878 - val_accuracy: 0.3333
# Epoch 191/200
# 1/1 [==============================] - 0s 61ms/step - loss: 9.6300e-05 - accuracy: 1.0000 - val_loss: 14.1924 - val_accuracy: 0.3333
# Epoch 192/200
# 1/1 [==============================] - 0s 61ms/step - loss: 9.5692e-05 - accuracy: 1.0000 - val_loss: 14.1979 - val_accuracy: 0.3333
# Epoch 193/200
# 1/1 [==============================] - 0s 60ms/step - loss: 9.5136e-05 - accuracy: 1.0000 - val_loss: 14.2040 - val_accuracy: 0.3333
# Epoch 194/200
# 1/1 [==============================] - 0s 67ms/step - loss: 9.4546e-05 - accuracy: 1.0000 - val_loss: 14.2106 - val_accuracy: 0.3333
# Epoch 195/200
# 1/1 [==============================] - 0s 60ms/step - loss: 9.3956e-05 - accuracy: 1.0000 - val_loss: 14.2164 - val_accuracy: 0.3333
# Epoch 196/200
# 1/1 [==============================] - 0s 60ms/step - loss: 9.3399e-05 - accuracy: 1.0000 - val_loss: 14.2212 - val_accuracy: 0.3333
# Epoch 197/200
# 1/1 [==============================] - 0s 60ms/step - loss: 9.2843e-05 - accuracy: 1.0000 - val_loss: 14.2264 - val_accuracy: 0.3333
# Epoch 198/200
# 1/1 [==============================] - 0s 59ms/step - loss: 9.2281e-05 - accuracy: 1.0000 - val_loss: 14.2323 - val_accuracy: 0.3333
# Epoch 199/200
# 1/1 [==============================] - 0s 71ms/step - loss: 9.1731e-05 - accuracy: 1.0000 - val_loss: 14.2388 - val_accuracy: 0.3333
# Epoch 200/200
# 1/1 [==============================] - 0s 65ms/step - loss: 9.1186e-05 - accuracy: 1.0000 - val_loss: 14.2413 - val_accuracy: 0.3333
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, esDAimag, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )

        # sólo muestra las imágenes no generadas por DA
        if not esDAimag[i]:
          strTitulo = 'Real: ' + clReal + ' / RNA: ' 
          strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

          # muestra comparación con la imagen
          fig = plt.figure()
          fig.suptitle( strTitulo )
          ax1 = fig.add_subplot(121)
          plot_image( x[i] )
          
          plt.tight_layout()
          fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, esDAimag_train, clases_map)
# Out:
# *** Resultados con datos de Entrenamiento:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         8
#   versicolor       0.80      1.00      0.89         8
#    virginica       1.00      0.75      0.86         8
#
#     accuracy                           0.92        24
#    macro avg       0.93      0.92      0.92        24
# weighted avg       0.93      0.92      0.92        24
#
#
# Matriz de Confusión:
#               p:versicolor  p:virginica  p:setosa
# r:versicolor             8            0         0
# r:virginica              2            6         0
# r:setosa                 0            0         8
#
#
#
# >Resultados:

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
#@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, esDAimag_test, clases_map)
# Out:
# 1/1 [==============================] - 0s 107ms/step - loss: 3.7612 - accuracy: 0.6667
#
# >Evaluación del Modelo:
#     - Error:  3.7612338066101074
#     - Exactitud:  66.66666865348816
#
#
#
#
# *** Resultados con datos de Prueba:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.67      0.80         3
#   versicolor       0.50      1.00      0.67         3
#    virginica       1.00      0.33      0.50         3
#
#     accuracy                           0.67         9
#    macro avg       0.83      0.67      0.66         9
# weighted avg       0.83      0.67      0.66         9
#
#
# Matriz de Confusión:
#               p:versicolor  p:virginica  p:setosa
# r:versicolor             3            0         0
# r:virginica              2            1         0
# r:setosa                 1            0         2
#
#
#
# >Resultados:
