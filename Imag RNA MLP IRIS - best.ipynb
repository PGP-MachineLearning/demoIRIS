# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation usando Keras para procesar imágenes e identificar TIPOS de Flores IRIS

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
import keras
from keras.layers import Input, Dense
from keras.models import Model
from keras.utils import plot_model
from sklearn.model_selection import train_test_split

from keras.utils import np_utils

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho = 24 #@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}
imagen_usar_generadas_data_augmentation = True #@param {type:"boolean"}

#@markdown ### Parámetros de la red:
rna_cant_neuronas_capas_ocultas = '1240, 120, 62, 12' #@param {type:"string"}
rna_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
rna_cant_epocas_entrenamiento = 500 #@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# indica si se usan las imágenes generadas por data augmentation
usarDA = imagen_usar_generadas_data_augmentation

# define tamaño de datos de entrada 
num_inputs = IMAGE_SHAPE[0] * IMAGE_SHAPE[1] * IMAGE_SHAPE[2]

# cantidad de neuronas ocultas 
##hidden_layers = [ num_inputs//5, num_inputs//20, num_inputs//100 ]
hidden_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(','):
  hidden_layers.append( int(val) )

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (rna_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if rna_cant_epocas_entrenamiento<1 else rna_cant_epocas_entrenamiento)

print ("Tamaño Imagen: ", IMAGE_SHAPE)
print("Configuración de RNA MLP Backpropagation definida: [", num_inputs, hidden_layers, ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Tamaño Imagen:  (24, 24, 3)
# Configuración de RNA MLP Backpropagation definida: [ 1728 [1240, 120, 62, 12] Softmax

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demo IRIS/imagenes' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
#@title Cargar imágenes
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            if usarDA or (not esImagDA): 
                
                # abre la imagen
                imag = Image.open(auxiPath + "/" + each_imagFN)
                
                # ajusta el tamaño
                if IMAGE_SHAPE[2]==1:              
                  tipoImage = 'L'
                else:                
                  tipoImage = 'RGB'
                imag = imag.convert(tipoImage)
                imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
                
                # transforma a un vector de nros
                arImag = np.array(imag)
                
                # agrega a los vectores
                classes_ori.append( each_dir )
                images_ori.append( arImag )
                esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  24
# - Imágenes cargadas:  24
# - Ejemplo  setosa   (24, 24, 3) :
# <PIL.Image.Image image mode=RGB size=24x24 at 0x7FD0D0B01410>
# > Para Prueba:
# - Clases cargadas:  9
# - Imágenes cargadas:  9
# - Ejemplo  setosa   (24, 24, 3) :
# <PIL.Image.Image image mode=RGB size=24x24 at 0x7FD0D0B01950>

# %%
#@title Preparar imágenes
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), num_inputs))  
  return np.array(auxiAr)

# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = np_utils.to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
if tipo_output_softMax:
  print(" - y_trainEnc (cant): ", len(y_trainEnc))
else:
  print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if tipo_output_softMax:
  print(" - y_testEnc (cant): ", len(y_testEnc))
else:
  print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (24, 1728)
#  - y_trainEnc (cant):  24
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (9, 1728)
#  - y_testEnc (cant):  9
#
#
# > Para Ambos:
#  - dictMapeo:  {'setosa': 0, 'versicolor': 1, 'virginica': 2}
#  - clases_map:  ['setosa', 'versicolor', 'virginica']
#
#  - Imagen reconstruida de  setosa ( 0  /  [1. 0. 0.] )

# %% [markdown]
# 5) Establecer el modelo para la RNA:

# %%
#@title Establecer modelo

opt_tipo = "Adadelta" #@param ["Gradiente Decreciente", "Adam", "Adadelta", "Adagrad", "Adamax", "Nadam", "FTRL"]
opt_learning_rate = 0.005 #@param {type: "number"}

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1 
for num_hid in hidden_layers:  

    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(num_hid, name=auxlayerName)(eachLay) # capas ocultas

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida


if opt_tipo == "Gradiente Decreciente":
  opt = keras.optimizers.SGD(learning_rate=opt_learning_rate)
elif opt_tipo == "Adam":
  opt = keras.optimizers.Adam(learning_rate=opt_learning_rate)
elif opt_tipo == "Adadelta":
  opt = keras.optimizers.Adadelta(learning_rate=opt_learning_rate)
elif opt_tipo == "Adagrad":
  opt = keras.optimizers.Adagrad(learning_rate=opt_learning_rate)
elif opt_tipo == "Adamax":
  opt = keras.optimizers.Adamax(learning_rate=opt_learning_rate)
elif opt_tipo == "Nadam":
  opt = keras.optimizers.Nadam(learning_rate=opt_learning_rate)
elif opt_tipo == "FTRL":
  opt = keras.optimizers.Ftrl(learning_rate=opt_learning_rate)
else:
  opt = keras.optimizers.Adam()

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  6  capas:
# Model: "RNA"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_img (InputLayer)       [(None, 1728)]            0
# _________________________________________________________________
# hidd_1 (Dense)               (None, 1240)              2143960
# _________________________________________________________________
# hidd_2 (Dense)               (None, 120)               148920
# _________________________________________________________________
# hidd_3 (Dense)               (None, 62)                7502
# _________________________________________________________________
# hidd_4 (Dense)               (None, 12)                756
# _________________________________________________________________
# output (Dense)               (None, 3)                 39
# =================================================================
# Total params: 2,301,177
# Trainable params: 2,301,177
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

activar_corte_por_estabilidad_error_val = False #@param {type:"boolean"}

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

if activar_corte_por_estabilidad_error_val:
  # se agrega un callBack para que corte 
  # si el error de validación no sigue bajando
  # y devuelva los mejores pesos obtenidos
  early_stopping_monitor = keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0.01,
      patience=20,
      verbose=0,
      mode='min',
      baseline=None,
      restore_best_weights=True
  )
  callbacksEntr = [early_stopping_monitor]
else:
  early_stopping_monitor = None
  callbacksEntr = []

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,),
          callbacks=callbacksEntr ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  24 ejemplos de entrenamiento:
#             se usan  21 ejemplos para entrenar
#             y  3 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/500
# 1/1 [==============================] - 1s 1s/step - loss: 1.9944 - accuracy: 0.2381 - val_loss: 0.7194 - val_accuracy: 0.6667
# Epoch 2/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.8000 - accuracy: 0.1905 - val_loss: 0.7668 - val_accuracy: 0.3333
# Epoch 3/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.6384 - accuracy: 0.1905 - val_loss: 0.8215 - val_accuracy: 0.3333
# Epoch 4/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.5050 - accuracy: 0.1905 - val_loss: 0.8820 - val_accuracy: 0.3333
# Epoch 5/500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.3985 - accuracy: 0.2381 - val_loss: 0.9484 - val_accuracy: 0.3333
# Epoch 6/500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.3194 - accuracy: 0.2381 - val_loss: 1.0161 - val_accuracy: 0.3333
# Epoch 7/500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.2650 - accuracy: 0.2857 - val_loss: 1.0771 - val_accuracy: 0.3333
# Epoch 8/500
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2290 - accuracy: 0.2381 - val_loss: 1.1256 - val_accuracy: 0.3333
# Epoch 9/500
# 1/1 [==============================] - 0s 31ms/step - loss: 1.2041 - accuracy: 0.2381 - val_loss: 1.1602 - val_accuracy: 0.3333
# Epoch 10/500
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1851 - accuracy: 0.2381 - val_loss: 1.1829 - val_accuracy: 0.3333
# Epoch 11/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.1690 - accuracy: 0.2381 - val_loss: 1.1967 - val_accuracy: 0.3333
# Epoch 12/500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.1541 - accuracy: 0.2857 - val_loss: 1.2044 - val_accuracy: 0.3333
# Epoch 13/500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.1399 - accuracy: 0.2857 - val_loss: 1.2080 - val_accuracy: 0.3333
# Epoch 14/500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.1261 - accuracy: 0.3333 - val_loss: 1.2091 - val_accuracy: 0.3333
# Epoch 15/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.1125 - accuracy: 0.3810 - val_loss: 1.2086 - val_accuracy: 0.3333
# Epoch 16/500
# 1/1 [==============================] - 0s 30ms/step - loss: 1.0991 - accuracy: 0.3810 - val_loss: 1.2071 - val_accuracy: 0.3333
# Epoch 17/500
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0860 - accuracy: 0.4286 - val_loss: 1.2051 - val_accuracy: 0.3333
# Epoch 18/500
# 1/1 [==============================] - 0s 33ms/step - loss: 1.0730 - accuracy: 0.4762 - val_loss: 1.2028 - val_accuracy: 0.3333
# Epoch 19/500
# 1/1 [==============================] - 0s 41ms/step - loss: 1.0602 - accuracy: 0.4762 - val_loss: 1.2004 - val_accuracy: 0.3333
# Epoch 20/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0475 - accuracy: 0.4762 - val_loss: 1.1979 - val_accuracy: 0.3333
# Epoch 21/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0351 - accuracy: 0.4762 - val_loss: 1.1954 - val_accuracy: 0.3333
# Epoch 22/500
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0228 - accuracy: 0.4762 - val_loss: 1.1930 - val_accuracy: 0.3333
# Epoch 23/500
# 1/1 [==============================] - 0s 32ms/step - loss: 1.0107 - accuracy: 0.4762 - val_loss: 1.1907 - val_accuracy: 0.3333
# Epoch 24/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9987 - accuracy: 0.4762 - val_loss: 1.1884 - val_accuracy: 0.3333
# Epoch 25/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9869 - accuracy: 0.4762 - val_loss: 1.1862 - val_accuracy: 0.3333
# Epoch 26/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9753 - accuracy: 0.4762 - val_loss: 1.1842 - val_accuracy: 0.3333
# Epoch 27/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9639 - accuracy: 0.5238 - val_loss: 1.1821 - val_accuracy: 0.3333
# Epoch 28/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.9526 - accuracy: 0.5238 - val_loss: 1.1802 - val_accuracy: 0.3333
# Epoch 29/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9415 - accuracy: 0.5714 - val_loss: 1.1784 - val_accuracy: 0.3333
# Epoch 30/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9305 - accuracy: 0.6190 - val_loss: 1.1766 - val_accuracy: 0.3333
# Epoch 31/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.9197 - accuracy: 0.6190 - val_loss: 1.1749 - val_accuracy: 0.3333
# Epoch 32/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.9090 - accuracy: 0.6190 - val_loss: 1.1733 - val_accuracy: 0.3333
# Epoch 33/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.8985 - accuracy: 0.6190 - val_loss: 1.1718 - val_accuracy: 0.3333
# Epoch 34/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8882 - accuracy: 0.6190 - val_loss: 1.1703 - val_accuracy: 0.3333
# Epoch 35/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.8780 - accuracy: 0.6190 - val_loss: 1.1689 - val_accuracy: 0.3333
# Epoch 36/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.8679 - accuracy: 0.6667 - val_loss: 1.1675 - val_accuracy: 0.3333
# Epoch 37/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8580 - accuracy: 0.6667 - val_loss: 1.1663 - val_accuracy: 0.3333
# Epoch 38/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.8482 - accuracy: 0.6667 - val_loss: 1.1650 - val_accuracy: 0.3333
# Epoch 39/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8385 - accuracy: 0.6667 - val_loss: 1.1639 - val_accuracy: 0.3333
# Epoch 40/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.8290 - accuracy: 0.6667 - val_loss: 1.1628 - val_accuracy: 0.3333
# Epoch 41/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8196 - accuracy: 0.7619 - val_loss: 1.1617 - val_accuracy: 0.3333
# Epoch 42/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.8103 - accuracy: 0.7619 - val_loss: 1.1607 - val_accuracy: 0.3333
# Epoch 43/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.8012 - accuracy: 0.7619 - val_loss: 1.1598 - val_accuracy: 0.3333
# Epoch 44/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7922 - accuracy: 0.7619 - val_loss: 1.1589 - val_accuracy: 0.3333
# Epoch 45/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.7833 - accuracy: 0.7619 - val_loss: 1.1581 - val_accuracy: 0.3333
# Epoch 46/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7746 - accuracy: 0.8095 - val_loss: 1.1573 - val_accuracy: 0.3333
# Epoch 47/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7659 - accuracy: 0.8095 - val_loss: 1.1565 - val_accuracy: 0.3333
# Epoch 48/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7574 - accuracy: 0.8095 - val_loss: 1.1558 - val_accuracy: 0.3333
# Epoch 49/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.7490 - accuracy: 0.8571 - val_loss: 1.1552 - val_accuracy: 0.3333
# Epoch 50/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7407 - accuracy: 0.8571 - val_loss: 1.1545 - val_accuracy: 0.3333
# Epoch 51/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.7325 - accuracy: 0.8571 - val_loss: 1.1539 - val_accuracy: 0.3333
# Epoch 52/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.7244 - accuracy: 0.8571 - val_loss: 1.1534 - val_accuracy: 0.3333
# Epoch 53/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.7164 - accuracy: 0.8571 - val_loss: 1.1529 - val_accuracy: 0.3333
# Epoch 54/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7085 - accuracy: 0.8571 - val_loss: 1.1524 - val_accuracy: 0.3333
# Epoch 55/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7008 - accuracy: 0.8571 - val_loss: 1.1520 - val_accuracy: 0.3333
# Epoch 56/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6931 - accuracy: 0.8571 - val_loss: 1.1516 - val_accuracy: 0.3333
# Epoch 57/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.6855 - accuracy: 0.9048 - val_loss: 1.1512 - val_accuracy: 0.3333
# Epoch 58/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6780 - accuracy: 0.9048 - val_loss: 1.1509 - val_accuracy: 0.3333
# Epoch 59/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6706 - accuracy: 0.9048 - val_loss: 1.1506 - val_accuracy: 0.3333
# Epoch 60/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6633 - accuracy: 0.9048 - val_loss: 1.1503 - val_accuracy: 0.3333
# Epoch 61/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6561 - accuracy: 0.9048 - val_loss: 1.1500 - val_accuracy: 0.3333
# Epoch 62/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6490 - accuracy: 0.9048 - val_loss: 1.1498 - val_accuracy: 0.3333
# Epoch 63/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6420 - accuracy: 0.9048 - val_loss: 1.1496 - val_accuracy: 0.3333
# Epoch 64/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6351 - accuracy: 0.9048 - val_loss: 1.1494 - val_accuracy: 0.3333
# Epoch 65/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6282 - accuracy: 0.9048 - val_loss: 1.1493 - val_accuracy: 0.3333
# Epoch 66/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6214 - accuracy: 0.9048 - val_loss: 1.1491 - val_accuracy: 0.3333
# Epoch 67/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.6148 - accuracy: 0.9048 - val_loss: 1.1490 - val_accuracy: 0.3333
# Epoch 68/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6081 - accuracy: 0.9048 - val_loss: 1.1489 - val_accuracy: 0.3333
# Epoch 69/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6016 - accuracy: 0.9048 - val_loss: 1.1489 - val_accuracy: 0.3333
# Epoch 70/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5952 - accuracy: 0.9048 - val_loss: 1.1488 - val_accuracy: 0.3333
# Epoch 71/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.5888 - accuracy: 0.9048 - val_loss: 1.1488 - val_accuracy: 0.3333
# Epoch 72/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5825 - accuracy: 0.9048 - val_loss: 1.1488 - val_accuracy: 0.3333
# Epoch 73/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5763 - accuracy: 0.9048 - val_loss: 1.1488 - val_accuracy: 0.3333
# Epoch 74/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.5701 - accuracy: 0.9048 - val_loss: 1.1489 - val_accuracy: 0.3333
# Epoch 75/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5640 - accuracy: 0.9048 - val_loss: 1.1489 - val_accuracy: 0.3333
# Epoch 76/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5580 - accuracy: 0.9048 - val_loss: 1.1490 - val_accuracy: 0.3333
# Epoch 77/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5521 - accuracy: 0.9048 - val_loss: 1.1491 - val_accuracy: 0.3333
# Epoch 78/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5462 - accuracy: 0.9048 - val_loss: 1.1492 - val_accuracy: 0.3333
# Epoch 79/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.5404 - accuracy: 0.9048 - val_loss: 1.1493 - val_accuracy: 0.3333
# Epoch 80/500
# 1/1 [==============================] - 0s 29ms/step - loss: 0.5347 - accuracy: 0.9048 - val_loss: 1.1494 - val_accuracy: 0.3333
# Epoch 81/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.5290 - accuracy: 0.9048 - val_loss: 1.1496 - val_accuracy: 0.3333
# Epoch 82/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.5234 - accuracy: 0.9048 - val_loss: 1.1498 - val_accuracy: 0.3333
# Epoch 83/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5178 - accuracy: 0.9048 - val_loss: 1.1499 - val_accuracy: 0.3333
# Epoch 84/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5124 - accuracy: 0.9524 - val_loss: 1.1501 - val_accuracy: 0.3333
# Epoch 85/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5069 - accuracy: 0.9524 - val_loss: 1.1503 - val_accuracy: 0.3333
# Epoch 86/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5016 - accuracy: 0.9524 - val_loss: 1.1505 - val_accuracy: 0.3333
# Epoch 87/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4963 - accuracy: 0.9524 - val_loss: 1.1508 - val_accuracy: 0.3333
# Epoch 88/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4910 - accuracy: 0.9524 - val_loss: 1.1510 - val_accuracy: 0.3333
# Epoch 89/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4859 - accuracy: 0.9524 - val_loss: 1.1512 - val_accuracy: 0.3333
# Epoch 90/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4807 - accuracy: 0.9524 - val_loss: 1.1515 - val_accuracy: 0.3333
# Epoch 91/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4757 - accuracy: 0.9524 - val_loss: 1.1518 - val_accuracy: 0.3333
# Epoch 92/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4707 - accuracy: 0.9524 - val_loss: 1.1521 - val_accuracy: 0.3333
# Epoch 93/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4657 - accuracy: 0.9524 - val_loss: 1.1523 - val_accuracy: 0.3333
# Epoch 94/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4608 - accuracy: 0.9524 - val_loss: 1.1526 - val_accuracy: 0.3333
# Epoch 95/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4559 - accuracy: 0.9524 - val_loss: 1.1530 - val_accuracy: 0.3333
# Epoch 96/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4511 - accuracy: 0.9524 - val_loss: 1.1533 - val_accuracy: 0.3333
# Epoch 97/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4464 - accuracy: 0.9524 - val_loss: 1.1536 - val_accuracy: 0.3333
# Epoch 98/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4417 - accuracy: 0.9524 - val_loss: 1.1539 - val_accuracy: 0.3333
# Epoch 99/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4371 - accuracy: 0.9524 - val_loss: 1.1543 - val_accuracy: 0.3333
# Epoch 100/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4325 - accuracy: 0.9524 - val_loss: 1.1546 - val_accuracy: 0.3333
# Epoch 101/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4279 - accuracy: 0.9524 - val_loss: 1.1550 - val_accuracy: 0.3333
# Epoch 102/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.4235 - accuracy: 0.9524 - val_loss: 1.1554 - val_accuracy: 0.3333
# Epoch 103/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.4190 - accuracy: 0.9524 - val_loss: 1.1557 - val_accuracy: 0.3333
# Epoch 104/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4146 - accuracy: 0.9524 - val_loss: 1.1561 - val_accuracy: 0.3333
# Epoch 105/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4103 - accuracy: 0.9524 - val_loss: 1.1565 - val_accuracy: 0.3333
# Epoch 106/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4060 - accuracy: 0.9524 - val_loss: 1.1569 - val_accuracy: 0.3333
# Epoch 107/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4017 - accuracy: 0.9524 - val_loss: 1.1573 - val_accuracy: 0.3333
# Epoch 108/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3975 - accuracy: 0.9524 - val_loss: 1.1577 - val_accuracy: 0.3333
# Epoch 109/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3934 - accuracy: 0.9524 - val_loss: 1.1582 - val_accuracy: 0.3333
# Epoch 110/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3892 - accuracy: 0.9524 - val_loss: 1.1586 - val_accuracy: 0.3333
# Epoch 111/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3852 - accuracy: 0.9524 - val_loss: 1.1590 - val_accuracy: 0.3333
# Epoch 112/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3811 - accuracy: 0.9524 - val_loss: 1.1594 - val_accuracy: 0.3333
# Epoch 113/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3772 - accuracy: 0.9524 - val_loss: 1.1599 - val_accuracy: 0.3333
# Epoch 114/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3732 - accuracy: 0.9524 - val_loss: 1.1603 - val_accuracy: 0.3333
# Epoch 115/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3693 - accuracy: 0.9524 - val_loss: 1.1608 - val_accuracy: 0.3333
# Epoch 116/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.3655 - accuracy: 0.9524 - val_loss: 1.1612 - val_accuracy: 0.3333
# Epoch 117/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3617 - accuracy: 0.9524 - val_loss: 1.1617 - val_accuracy: 0.3333
# Epoch 118/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3579 - accuracy: 0.9524 - val_loss: 1.1622 - val_accuracy: 0.3333
# Epoch 119/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3541 - accuracy: 0.9524 - val_loss: 1.1626 - val_accuracy: 0.3333
# Epoch 120/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3505 - accuracy: 0.9524 - val_loss: 1.1631 - val_accuracy: 0.3333
# Epoch 121/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3468 - accuracy: 0.9524 - val_loss: 1.1636 - val_accuracy: 0.3333
# Epoch 122/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3432 - accuracy: 0.9524 - val_loss: 1.1641 - val_accuracy: 0.3333
# Epoch 123/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3396 - accuracy: 0.9524 - val_loss: 1.1646 - val_accuracy: 0.3333
# Epoch 124/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3361 - accuracy: 0.9524 - val_loss: 1.1651 - val_accuracy: 0.3333
# Epoch 125/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.3326 - accuracy: 0.9524 - val_loss: 1.1656 - val_accuracy: 0.3333
# Epoch 126/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.3291 - accuracy: 0.9524 - val_loss: 1.1661 - val_accuracy: 0.3333
# Epoch 127/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3257 - accuracy: 0.9524 - val_loss: 1.1666 - val_accuracy: 0.3333
# Epoch 128/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3223 - accuracy: 0.9524 - val_loss: 1.1671 - val_accuracy: 0.3333
# Epoch 129/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3190 - accuracy: 1.0000 - val_loss: 1.1676 - val_accuracy: 0.3333
# Epoch 130/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3157 - accuracy: 1.0000 - val_loss: 1.1681 - val_accuracy: 0.3333
# Epoch 131/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3124 - accuracy: 1.0000 - val_loss: 1.1686 - val_accuracy: 0.3333
# Epoch 132/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3091 - accuracy: 1.0000 - val_loss: 1.1692 - val_accuracy: 0.3333
# Epoch 133/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.3059 - accuracy: 1.0000 - val_loss: 1.1697 - val_accuracy: 0.3333
# Epoch 134/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.3028 - accuracy: 1.0000 - val_loss: 1.1702 - val_accuracy: 0.3333
# Epoch 135/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2996 - accuracy: 1.0000 - val_loss: 1.1707 - val_accuracy: 0.3333
# Epoch 136/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2965 - accuracy: 1.0000 - val_loss: 1.1713 - val_accuracy: 0.3333
# Epoch 137/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2935 - accuracy: 1.0000 - val_loss: 1.1718 - val_accuracy: 0.3333
# Epoch 138/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2904 - accuracy: 1.0000 - val_loss: 1.1724 - val_accuracy: 0.3333
# Epoch 139/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2874 - accuracy: 1.0000 - val_loss: 1.1729 - val_accuracy: 0.3333
# Epoch 140/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2845 - accuracy: 1.0000 - val_loss: 1.1734 - val_accuracy: 0.3333
# Epoch 141/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2815 - accuracy: 1.0000 - val_loss: 1.1740 - val_accuracy: 0.3333
# Epoch 142/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2786 - accuracy: 1.0000 - val_loss: 1.1745 - val_accuracy: 0.3333
# Epoch 143/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2758 - accuracy: 1.0000 - val_loss: 1.1751 - val_accuracy: 0.3333
# Epoch 144/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2729 - accuracy: 1.0000 - val_loss: 1.1756 - val_accuracy: 0.3333
# Epoch 145/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2701 - accuracy: 1.0000 - val_loss: 1.1762 - val_accuracy: 0.3333
# Epoch 146/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2673 - accuracy: 1.0000 - val_loss: 1.1768 - val_accuracy: 0.3333
# Epoch 147/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2646 - accuracy: 1.0000 - val_loss: 1.1773 - val_accuracy: 0.0000e+00
# Epoch 148/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2619 - accuracy: 1.0000 - val_loss: 1.1779 - val_accuracy: 0.0000e+00
# Epoch 149/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2592 - accuracy: 1.0000 - val_loss: 1.1784 - val_accuracy: 0.0000e+00
# Epoch 150/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2565 - accuracy: 1.0000 - val_loss: 1.1790 - val_accuracy: 0.0000e+00
# Epoch 151/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2539 - accuracy: 1.0000 - val_loss: 1.1796 - val_accuracy: 0.0000e+00
# Epoch 152/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2513 - accuracy: 1.0000 - val_loss: 1.1801 - val_accuracy: 0.0000e+00
# Epoch 153/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2487 - accuracy: 1.0000 - val_loss: 1.1807 - val_accuracy: 0.0000e+00
# Epoch 154/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2462 - accuracy: 1.0000 - val_loss: 1.1813 - val_accuracy: 0.0000e+00
# Epoch 155/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2437 - accuracy: 1.0000 - val_loss: 1.1819 - val_accuracy: 0.0000e+00
# Epoch 156/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2412 - accuracy: 1.0000 - val_loss: 1.1824 - val_accuracy: 0.0000e+00
# Epoch 157/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2387 - accuracy: 1.0000 - val_loss: 1.1830 - val_accuracy: 0.0000e+00
# Epoch 158/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2363 - accuracy: 1.0000 - val_loss: 1.1836 - val_accuracy: 0.0000e+00
# Epoch 159/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2339 - accuracy: 1.0000 - val_loss: 1.1842 - val_accuracy: 0.0000e+00
# Epoch 160/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2315 - accuracy: 1.0000 - val_loss: 1.1847 - val_accuracy: 0.0000e+00
# Epoch 161/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2291 - accuracy: 1.0000 - val_loss: 1.1853 - val_accuracy: 0.0000e+00
# Epoch 162/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2268 - accuracy: 1.0000 - val_loss: 1.1859 - val_accuracy: 0.0000e+00
# Epoch 163/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2245 - accuracy: 1.0000 - val_loss: 1.1865 - val_accuracy: 0.0000e+00
# Epoch 164/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2222 - accuracy: 1.0000 - val_loss: 1.1871 - val_accuracy: 0.0000e+00
# Epoch 165/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2200 - accuracy: 1.0000 - val_loss: 1.1876 - val_accuracy: 0.0000e+00
# Epoch 166/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2178 - accuracy: 1.0000 - val_loss: 1.1882 - val_accuracy: 0.0000e+00
# Epoch 167/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2156 - accuracy: 1.0000 - val_loss: 1.1888 - val_accuracy: 0.0000e+00
# Epoch 168/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2134 - accuracy: 1.0000 - val_loss: 1.1894 - val_accuracy: 0.0000e+00
# Epoch 169/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.2112 - accuracy: 1.0000 - val_loss: 1.1900 - val_accuracy: 0.0000e+00
# Epoch 170/500
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2091 - accuracy: 1.0000 - val_loss: 1.1906 - val_accuracy: 0.0000e+00
# Epoch 171/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2070 - accuracy: 1.0000 - val_loss: 1.1911 - val_accuracy: 0.0000e+00
# Epoch 172/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2049 - accuracy: 1.0000 - val_loss: 1.1917 - val_accuracy: 0.0000e+00
# Epoch 173/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2029 - accuracy: 1.0000 - val_loss: 1.1923 - val_accuracy: 0.0000e+00
# Epoch 174/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2008 - accuracy: 1.0000 - val_loss: 1.1929 - val_accuracy: 0.0000e+00
# Epoch 175/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1988 - accuracy: 1.0000 - val_loss: 1.1935 - val_accuracy: 0.0000e+00
# Epoch 176/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1969 - accuracy: 1.0000 - val_loss: 1.1941 - val_accuracy: 0.0000e+00
# Epoch 177/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1949 - accuracy: 1.0000 - val_loss: 1.1947 - val_accuracy: 0.0000e+00
# Epoch 178/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1929 - accuracy: 1.0000 - val_loss: 1.1953 - val_accuracy: 0.0000e+00
# Epoch 179/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1910 - accuracy: 1.0000 - val_loss: 1.1958 - val_accuracy: 0.0000e+00
# Epoch 180/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1891 - accuracy: 1.0000 - val_loss: 1.1964 - val_accuracy: 0.0000e+00
# Epoch 181/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1872 - accuracy: 1.0000 - val_loss: 1.1970 - val_accuracy: 0.0000e+00
# Epoch 182/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1854 - accuracy: 1.0000 - val_loss: 1.1976 - val_accuracy: 0.0000e+00
# Epoch 183/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1836 - accuracy: 1.0000 - val_loss: 1.1982 - val_accuracy: 0.0000e+00
# Epoch 184/500
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1817 - accuracy: 1.0000 - val_loss: 1.1988 - val_accuracy: 0.0000e+00
# Epoch 185/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1799 - accuracy: 1.0000 - val_loss: 1.1994 - val_accuracy: 0.0000e+00
# Epoch 186/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1782 - accuracy: 1.0000 - val_loss: 1.2000 - val_accuracy: 0.0000e+00
# Epoch 187/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1764 - accuracy: 1.0000 - val_loss: 1.2006 - val_accuracy: 0.0000e+00
# Epoch 188/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1747 - accuracy: 1.0000 - val_loss: 1.2011 - val_accuracy: 0.0000e+00
# Epoch 189/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1730 - accuracy: 1.0000 - val_loss: 1.2017 - val_accuracy: 0.0000e+00
# Epoch 190/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1713 - accuracy: 1.0000 - val_loss: 1.2023 - val_accuracy: 0.0000e+00
# Epoch 191/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1696 - accuracy: 1.0000 - val_loss: 1.2029 - val_accuracy: 0.0000e+00
# Epoch 192/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1679 - accuracy: 1.0000 - val_loss: 1.2035 - val_accuracy: 0.0000e+00
# Epoch 193/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1663 - accuracy: 1.0000 - val_loss: 1.2041 - val_accuracy: 0.0000e+00
# Epoch 194/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1647 - accuracy: 1.0000 - val_loss: 1.2047 - val_accuracy: 0.0000e+00
# Epoch 195/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1631 - accuracy: 1.0000 - val_loss: 1.2052 - val_accuracy: 0.0000e+00
# Epoch 196/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1615 - accuracy: 1.0000 - val_loss: 1.2058 - val_accuracy: 0.0000e+00
# Epoch 197/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1599 - accuracy: 1.0000 - val_loss: 1.2064 - val_accuracy: 0.0000e+00
# Epoch 198/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1584 - accuracy: 1.0000 - val_loss: 1.2070 - val_accuracy: 0.0000e+00
# Epoch 199/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1568 - accuracy: 1.0000 - val_loss: 1.2076 - val_accuracy: 0.0000e+00
# Epoch 200/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1553 - accuracy: 1.0000 - val_loss: 1.2082 - val_accuracy: 0.0000e+00
# Epoch 201/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1538 - accuracy: 1.0000 - val_loss: 1.2087 - val_accuracy: 0.0000e+00
# Epoch 202/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1523 - accuracy: 1.0000 - val_loss: 1.2093 - val_accuracy: 0.0000e+00
# Epoch 203/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1509 - accuracy: 1.0000 - val_loss: 1.2099 - val_accuracy: 0.0000e+00
# Epoch 204/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1494 - accuracy: 1.0000 - val_loss: 1.2105 - val_accuracy: 0.0000e+00
# Epoch 205/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1480 - accuracy: 1.0000 - val_loss: 1.2111 - val_accuracy: 0.0000e+00
# Epoch 206/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1466 - accuracy: 1.0000 - val_loss: 1.2116 - val_accuracy: 0.0000e+00
# Epoch 207/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1452 - accuracy: 1.0000 - val_loss: 1.2122 - val_accuracy: 0.0000e+00
# Epoch 208/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1438 - accuracy: 1.0000 - val_loss: 1.2128 - val_accuracy: 0.0000e+00
# Epoch 209/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1424 - accuracy: 1.0000 - val_loss: 1.2134 - val_accuracy: 0.0000e+00
# Epoch 210/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1411 - accuracy: 1.0000 - val_loss: 1.2139 - val_accuracy: 0.0000e+00
# Epoch 211/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1397 - accuracy: 1.0000 - val_loss: 1.2145 - val_accuracy: 0.0000e+00
# Epoch 212/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.1384 - accuracy: 1.0000 - val_loss: 1.2151 - val_accuracy: 0.0000e+00
# Epoch 213/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1371 - accuracy: 1.0000 - val_loss: 1.2157 - val_accuracy: 0.0000e+00
# Epoch 214/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1358 - accuracy: 1.0000 - val_loss: 1.2162 - val_accuracy: 0.0000e+00
# Epoch 215/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1346 - accuracy: 1.0000 - val_loss: 1.2168 - val_accuracy: 0.0000e+00
# Epoch 216/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1333 - accuracy: 1.0000 - val_loss: 1.2174 - val_accuracy: 0.0000e+00
# Epoch 217/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1320 - accuracy: 1.0000 - val_loss: 1.2179 - val_accuracy: 0.0000e+00
# Epoch 218/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1308 - accuracy: 1.0000 - val_loss: 1.2185 - val_accuracy: 0.0000e+00
# Epoch 219/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1296 - accuracy: 1.0000 - val_loss: 1.2191 - val_accuracy: 0.0000e+00
# Epoch 220/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1284 - accuracy: 1.0000 - val_loss: 1.2196 - val_accuracy: 0.0000e+00
# Epoch 221/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1272 - accuracy: 1.0000 - val_loss: 1.2202 - val_accuracy: 0.0000e+00
# Epoch 222/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1260 - accuracy: 1.0000 - val_loss: 1.2208 - val_accuracy: 0.0000e+00
# Epoch 223/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1248 - accuracy: 1.0000 - val_loss: 1.2213 - val_accuracy: 0.0000e+00
# Epoch 224/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1237 - accuracy: 1.0000 - val_loss: 1.2219 - val_accuracy: 0.0000e+00
# Epoch 225/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1225 - accuracy: 1.0000 - val_loss: 1.2224 - val_accuracy: 0.0000e+00
# Epoch 226/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1214 - accuracy: 1.0000 - val_loss: 1.2230 - val_accuracy: 0.0000e+00
# Epoch 227/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1203 - accuracy: 1.0000 - val_loss: 1.2236 - val_accuracy: 0.0000e+00
# Epoch 228/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1192 - accuracy: 1.0000 - val_loss: 1.2241 - val_accuracy: 0.0000e+00
# Epoch 229/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1181 - accuracy: 1.0000 - val_loss: 1.2247 - val_accuracy: 0.0000e+00
# Epoch 230/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1170 - accuracy: 1.0000 - val_loss: 1.2252 - val_accuracy: 0.0000e+00
# Epoch 231/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1160 - accuracy: 1.0000 - val_loss: 1.2258 - val_accuracy: 0.0000e+00
# Epoch 232/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1149 - accuracy: 1.0000 - val_loss: 1.2263 - val_accuracy: 0.0000e+00
# Epoch 233/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1139 - accuracy: 1.0000 - val_loss: 1.2269 - val_accuracy: 0.0000e+00
# Epoch 234/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1128 - accuracy: 1.0000 - val_loss: 1.2274 - val_accuracy: 0.0000e+00
# Epoch 235/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1118 - accuracy: 1.0000 - val_loss: 1.2280 - val_accuracy: 0.0000e+00
# Epoch 236/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1108 - accuracy: 1.0000 - val_loss: 1.2285 - val_accuracy: 0.0000e+00
# Epoch 237/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1098 - accuracy: 1.0000 - val_loss: 1.2291 - val_accuracy: 0.0000e+00
# Epoch 238/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1088 - accuracy: 1.0000 - val_loss: 1.2296 - val_accuracy: 0.0000e+00
# Epoch 239/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1078 - accuracy: 1.0000 - val_loss: 1.2302 - val_accuracy: 0.0000e+00
# Epoch 240/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1069 - accuracy: 1.0000 - val_loss: 1.2307 - val_accuracy: 0.0000e+00
# Epoch 241/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1059 - accuracy: 1.0000 - val_loss: 1.2312 - val_accuracy: 0.0000e+00
# Epoch 242/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1050 - accuracy: 1.0000 - val_loss: 1.2318 - val_accuracy: 0.0000e+00
# Epoch 243/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1041 - accuracy: 1.0000 - val_loss: 1.2323 - val_accuracy: 0.0000e+00
# Epoch 244/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1031 - accuracy: 1.0000 - val_loss: 1.2328 - val_accuracy: 0.0000e+00
# Epoch 245/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1022 - accuracy: 1.0000 - val_loss: 1.2334 - val_accuracy: 0.0000e+00
# Epoch 246/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1013 - accuracy: 1.0000 - val_loss: 1.2339 - val_accuracy: 0.0000e+00
# Epoch 247/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1004 - accuracy: 1.0000 - val_loss: 1.2344 - val_accuracy: 0.0000e+00
# Epoch 248/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0995 - accuracy: 1.0000 - val_loss: 1.2350 - val_accuracy: 0.0000e+00
# Epoch 249/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0987 - accuracy: 1.0000 - val_loss: 1.2355 - val_accuracy: 0.0000e+00
# Epoch 250/500
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0978 - accuracy: 1.0000 - val_loss: 1.2360 - val_accuracy: 0.0000e+00
# Epoch 251/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 1.2366 - val_accuracy: 0.0000e+00
# Epoch 252/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0961 - accuracy: 1.0000 - val_loss: 1.2371 - val_accuracy: 0.0000e+00
# Epoch 253/500
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0953 - accuracy: 1.0000 - val_loss: 1.2376 - val_accuracy: 0.0000e+00
# Epoch 254/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0945 - accuracy: 1.0000 - val_loss: 1.2381 - val_accuracy: 0.0000e+00
# Epoch 255/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0936 - accuracy: 1.0000 - val_loss: 1.2386 - val_accuracy: 0.0000e+00
# Epoch 256/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 1.2392 - val_accuracy: 0.0000e+00
# Epoch 257/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0920 - accuracy: 1.0000 - val_loss: 1.2397 - val_accuracy: 0.0000e+00
# Epoch 258/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0912 - accuracy: 1.0000 - val_loss: 1.2402 - val_accuracy: 0.0000e+00
# Epoch 259/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0905 - accuracy: 1.0000 - val_loss: 1.2407 - val_accuracy: 0.0000e+00
# Epoch 260/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0897 - accuracy: 1.0000 - val_loss: 1.2412 - val_accuracy: 0.0000e+00
# Epoch 261/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0889 - accuracy: 1.0000 - val_loss: 1.2417 - val_accuracy: 0.0000e+00
# Epoch 262/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0882 - accuracy: 1.0000 - val_loss: 1.2422 - val_accuracy: 0.0000e+00
# Epoch 263/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0874 - accuracy: 1.0000 - val_loss: 1.2428 - val_accuracy: 0.0000e+00
# Epoch 264/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0867 - accuracy: 1.0000 - val_loss: 1.2433 - val_accuracy: 0.0000e+00
# Epoch 265/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0860 - accuracy: 1.0000 - val_loss: 1.2438 - val_accuracy: 0.0000e+00
# Epoch 266/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0852 - accuracy: 1.0000 - val_loss: 1.2443 - val_accuracy: 0.0000e+00
# Epoch 267/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0845 - accuracy: 1.0000 - val_loss: 1.2448 - val_accuracy: 0.0000e+00
# Epoch 268/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0838 - accuracy: 1.0000 - val_loss: 1.2453 - val_accuracy: 0.0000e+00
# Epoch 269/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0831 - accuracy: 1.0000 - val_loss: 1.2458 - val_accuracy: 0.0000e+00
# Epoch 270/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0824 - accuracy: 1.0000 - val_loss: 1.2463 - val_accuracy: 0.0000e+00
# Epoch 271/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 1.2468 - val_accuracy: 0.0000e+00
# Epoch 272/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0810 - accuracy: 1.0000 - val_loss: 1.2473 - val_accuracy: 0.0000e+00
# Epoch 273/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0804 - accuracy: 1.0000 - val_loss: 1.2477 - val_accuracy: 0.0000e+00
# Epoch 274/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0797 - accuracy: 1.0000 - val_loss: 1.2482 - val_accuracy: 0.0000e+00
# Epoch 275/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0791 - accuracy: 1.0000 - val_loss: 1.2487 - val_accuracy: 0.0000e+00
# Epoch 276/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0784 - accuracy: 1.0000 - val_loss: 1.2492 - val_accuracy: 0.0000e+00
# Epoch 277/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 1.2497 - val_accuracy: 0.0000e+00
# Epoch 278/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0771 - accuracy: 1.0000 - val_loss: 1.2502 - val_accuracy: 0.0000e+00
# Epoch 279/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0765 - accuracy: 1.0000 - val_loss: 1.2507 - val_accuracy: 0.0000e+00
# Epoch 280/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0759 - accuracy: 1.0000 - val_loss: 1.2512 - val_accuracy: 0.0000e+00
# Epoch 281/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 1.2516 - val_accuracy: 0.0000e+00
# Epoch 282/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 1.2521 - val_accuracy: 0.0000e+00
# Epoch 283/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 1.2526 - val_accuracy: 0.0000e+00
# Epoch 284/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 1.2531 - val_accuracy: 0.0000e+00
# Epoch 285/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0729 - accuracy: 1.0000 - val_loss: 1.2535 - val_accuracy: 0.0000e+00
# Epoch 286/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0723 - accuracy: 1.0000 - val_loss: 1.2540 - val_accuracy: 0.0000e+00
# Epoch 287/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0717 - accuracy: 1.0000 - val_loss: 1.2545 - val_accuracy: 0.0000e+00
# Epoch 288/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0711 - accuracy: 1.0000 - val_loss: 1.2549 - val_accuracy: 0.0000e+00
# Epoch 289/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0706 - accuracy: 1.0000 - val_loss: 1.2554 - val_accuracy: 0.0000e+00
# Epoch 290/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0700 - accuracy: 1.0000 - val_loss: 1.2559 - val_accuracy: 0.0000e+00
# Epoch 291/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0695 - accuracy: 1.0000 - val_loss: 1.2563 - val_accuracy: 0.0000e+00
# Epoch 292/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0689 - accuracy: 1.0000 - val_loss: 1.2568 - val_accuracy: 0.0000e+00
# Epoch 293/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0684 - accuracy: 1.0000 - val_loss: 1.2573 - val_accuracy: 0.0000e+00
# Epoch 294/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0678 - accuracy: 1.0000 - val_loss: 1.2577 - val_accuracy: 0.0000e+00
# Epoch 295/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0673 - accuracy: 1.0000 - val_loss: 1.2582 - val_accuracy: 0.0000e+00
# Epoch 296/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0668 - accuracy: 1.0000 - val_loss: 1.2586 - val_accuracy: 0.0000e+00
# Epoch 297/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0663 - accuracy: 1.0000 - val_loss: 1.2591 - val_accuracy: 0.0000e+00
# Epoch 298/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0658 - accuracy: 1.0000 - val_loss: 1.2595 - val_accuracy: 0.0000e+00
# Epoch 299/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0652 - accuracy: 1.0000 - val_loss: 1.2600 - val_accuracy: 0.0000e+00
# Epoch 300/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 1.2604 - val_accuracy: 0.0000e+00
# Epoch 301/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0642 - accuracy: 1.0000 - val_loss: 1.2609 - val_accuracy: 0.0000e+00
# Epoch 302/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0638 - accuracy: 1.0000 - val_loss: 1.2613 - val_accuracy: 0.0000e+00
# Epoch 303/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0633 - accuracy: 1.0000 - val_loss: 1.2618 - val_accuracy: 0.0000e+00
# Epoch 304/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0628 - accuracy: 1.0000 - val_loss: 1.2622 - val_accuracy: 0.0000e+00
# Epoch 305/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 1.2627 - val_accuracy: 0.0000e+00
# Epoch 306/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0618 - accuracy: 1.0000 - val_loss: 1.2631 - val_accuracy: 0.0000e+00
# Epoch 307/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0614 - accuracy: 1.0000 - val_loss: 1.2635 - val_accuracy: 0.0000e+00
# Epoch 308/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0609 - accuracy: 1.0000 - val_loss: 1.2640 - val_accuracy: 0.0000e+00
# Epoch 309/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0604 - accuracy: 1.0000 - val_loss: 1.2644 - val_accuracy: 0.0000e+00
# Epoch 310/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0600 - accuracy: 1.0000 - val_loss: 1.2649 - val_accuracy: 0.0000e+00
# Epoch 311/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0595 - accuracy: 1.0000 - val_loss: 1.2653 - val_accuracy: 0.0000e+00
# Epoch 312/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0591 - accuracy: 1.0000 - val_loss: 1.2657 - val_accuracy: 0.0000e+00
# Epoch 313/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 1.2661 - val_accuracy: 0.0000e+00
# Epoch 314/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 1.2666 - val_accuracy: 0.0000e+00
# Epoch 315/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 1.2670 - val_accuracy: 0.0000e+00
# Epoch 316/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0574 - accuracy: 1.0000 - val_loss: 1.2674 - val_accuracy: 0.0000e+00
# Epoch 317/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0569 - accuracy: 1.0000 - val_loss: 1.2678 - val_accuracy: 0.0000e+00
# Epoch 318/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 1.2683 - val_accuracy: 0.0000e+00
# Epoch 319/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0561 - accuracy: 1.0000 - val_loss: 1.2687 - val_accuracy: 0.0000e+00
# Epoch 320/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 1.2691 - val_accuracy: 0.0000e+00
# Epoch 321/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0553 - accuracy: 1.0000 - val_loss: 1.2695 - val_accuracy: 0.0000e+00
# Epoch 322/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 1.2699 - val_accuracy: 0.0000e+00
# Epoch 323/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0545 - accuracy: 1.0000 - val_loss: 1.2703 - val_accuracy: 0.0000e+00
# Epoch 324/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 1.2708 - val_accuracy: 0.0000e+00
# Epoch 325/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 1.2712 - val_accuracy: 0.0000e+00
# Epoch 326/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 1.2716 - val_accuracy: 0.0000e+00
# Epoch 327/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 1.2720 - val_accuracy: 0.0000e+00
# Epoch 328/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0526 - accuracy: 1.0000 - val_loss: 1.2724 - val_accuracy: 0.0000e+00
# Epoch 329/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0522 - accuracy: 1.0000 - val_loss: 1.2728 - val_accuracy: 0.0000e+00
# Epoch 330/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0518 - accuracy: 1.0000 - val_loss: 1.2732 - val_accuracy: 0.0000e+00
# Epoch 331/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 1.2736 - val_accuracy: 0.0000e+00
# Epoch 332/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 1.2740 - val_accuracy: 0.0000e+00
# Epoch 333/500
# ...
# Epoch 392/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 1.2955 - val_accuracy: 0.0000e+00
# Epoch 393/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 1.2958 - val_accuracy: 0.0000e+00
# Epoch 394/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 1.2961 - val_accuracy: 0.0000e+00
# Epoch 395/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.2964 - val_accuracy: 0.0000e+00
# Epoch 396/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0338 - accuracy: 1.0000 - val_loss: 1.2968 - val_accuracy: 0.0000e+00
# Epoch 397/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 1.2971 - val_accuracy: 0.0000e+00
# Epoch 398/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 1.2974 - val_accuracy: 0.0000e+00
# Epoch 399/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 1.2977 - val_accuracy: 0.0000e+00
# Epoch 400/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 1.2980 - val_accuracy: 0.0000e+00
# Epoch 401/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 1.2983 - val_accuracy: 0.0000e+00
# Epoch 402/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 1.2986 - val_accuracy: 0.0000e+00
# Epoch 403/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 1.2989 - val_accuracy: 0.0000e+00
# Epoch 404/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 1.2993 - val_accuracy: 0.0000e+00
# Epoch 405/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 1.2996 - val_accuracy: 0.0000e+00
# Epoch 406/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 1.2999 - val_accuracy: 0.0000e+00
# Epoch 407/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 1.3002 - val_accuracy: 0.0000e+00
# Epoch 408/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 1.3005 - val_accuracy: 0.0000e+00
# Epoch 409/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 1.3008 - val_accuracy: 0.0000e+00
# Epoch 410/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0312 - accuracy: 1.0000 - val_loss: 1.3011 - val_accuracy: 0.0000e+00
# Epoch 411/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 1.3014 - val_accuracy: 0.0000e+00
# Epoch 412/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 1.3017 - val_accuracy: 0.0000e+00
# Epoch 413/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0307 - accuracy: 1.0000 - val_loss: 1.3020 - val_accuracy: 0.0000e+00
# Epoch 414/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 1.3023 - val_accuracy: 0.0000e+00
# Epoch 415/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 1.3026 - val_accuracy: 0.0000e+00
# Epoch 416/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 1.3029 - val_accuracy: 0.0000e+00
# Epoch 417/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 1.3032 - val_accuracy: 0.0000e+00
# Epoch 418/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 1.3035 - val_accuracy: 0.0000e+00
# Epoch 419/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 1.3038 - val_accuracy: 0.0000e+00
# Epoch 420/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 1.3041 - val_accuracy: 0.0000e+00
# Epoch 421/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 1.3044 - val_accuracy: 0.0000e+00
# Epoch 422/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 1.3046 - val_accuracy: 0.0000e+00
# Epoch 423/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 1.3049 - val_accuracy: 0.0000e+00
# Epoch 424/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 1.3052 - val_accuracy: 0.0000e+00
# Epoch 425/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 1.3055 - val_accuracy: 0.0000e+00
# Epoch 426/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 1.3058 - val_accuracy: 0.0000e+00
# Epoch 427/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 1.3061 - val_accuracy: 0.0000e+00
# Epoch 428/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.3064 - val_accuracy: 0.0000e+00
# Epoch 429/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 1.3067 - val_accuracy: 0.0000e+00
# Epoch 430/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 1.3069 - val_accuracy: 0.0000e+00
# Epoch 431/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 1.3072 - val_accuracy: 0.0000e+00
# Epoch 432/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 1.3075 - val_accuracy: 0.0000e+00
# Epoch 433/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 1.3078 - val_accuracy: 0.0000e+00
# Epoch 434/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 1.3081 - val_accuracy: 0.0000e+00
# Epoch 435/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 1.3083 - val_accuracy: 0.0000e+00
# Epoch 436/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 1.3086 - val_accuracy: 0.0000e+00
# Epoch 437/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 1.3089 - val_accuracy: 0.0000e+00
# Epoch 438/500
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 1.3092 - val_accuracy: 0.0000e+00
# Epoch 439/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 1.3095 - val_accuracy: 0.0000e+00
# Epoch 440/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 1.3097 - val_accuracy: 0.0000e+00
# Epoch 441/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 1.3100 - val_accuracy: 0.0000e+00
# Epoch 442/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 1.3103 - val_accuracy: 0.0000e+00
# Epoch 443/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 1.3106 - val_accuracy: 0.0000e+00
# Epoch 444/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 1.3108 - val_accuracy: 0.0000e+00
# Epoch 445/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 1.3111 - val_accuracy: 0.0000e+00
# Epoch 446/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 1.3114 - val_accuracy: 0.0000e+00
# Epoch 447/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 1.3116 - val_accuracy: 0.0000e+00
# Epoch 448/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 1.3119 - val_accuracy: 0.0000e+00
# Epoch 449/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 1.3122 - val_accuracy: 0.0000e+00
# Epoch 450/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 1.3125 - val_accuracy: 0.0000e+00
# Epoch 451/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 1.3127 - val_accuracy: 0.0000e+00
# Epoch 452/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 1.3130 - val_accuracy: 0.0000e+00
# Epoch 453/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 1.3133 - val_accuracy: 0.0000e+00
# Epoch 454/500
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 1.3135 - val_accuracy: 0.0000e+00
# Epoch 455/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 1.3138 - val_accuracy: 0.0000e+00
# Epoch 456/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 1.3140 - val_accuracy: 0.0000e+00
# Epoch 457/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 1.3143 - val_accuracy: 0.0000e+00
# Epoch 458/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 1.3146 - val_accuracy: 0.0000e+00
# Epoch 459/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 1.3148 - val_accuracy: 0.0000e+00
# Epoch 460/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 1.3151 - val_accuracy: 0.0000e+00
# Epoch 461/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 1.3154 - val_accuracy: 0.0000e+00
# Epoch 462/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 1.3156 - val_accuracy: 0.0000e+00
# Epoch 463/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 1.3159 - val_accuracy: 0.0000e+00
# Epoch 464/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 1.3161 - val_accuracy: 0.0000e+00
# Epoch 465/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 1.3164 - val_accuracy: 0.0000e+00
# Epoch 466/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 1.3166 - val_accuracy: 0.0000e+00
# Epoch 467/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 1.3169 - val_accuracy: 0.0000e+00
# Epoch 468/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 1.3172 - val_accuracy: 0.0000e+00
# Epoch 469/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 1.3174 - val_accuracy: 0.0000e+00
# Epoch 470/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 1.3177 - val_accuracy: 0.0000e+00
# Epoch 471/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 1.3179 - val_accuracy: 0.0000e+00
# Epoch 472/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 1.3182 - val_accuracy: 0.0000e+00
# Epoch 473/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 1.3184 - val_accuracy: 0.0000e+00
# Epoch 474/500
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 1.3187 - val_accuracy: 0.0000e+00
# Epoch 475/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 1.3189 - val_accuracy: 0.0000e+00
# Epoch 476/500
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 1.3192 - val_accuracy: 0.0000e+00
# Epoch 477/500
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 1.3194 - val_accuracy: 0.0000e+00
# Epoch 478/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0221 - accuracy: 1.0000 - val_loss: 1.3197 - val_accuracy: 0.0000e+00
# Epoch 479/500
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 1.3199 - val_accuracy: 0.0000e+00
# Epoch 480/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 1.3202 - val_accuracy: 0.0000e+00
# Epoch 481/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 1.3204 - val_accuracy: 0.0000e+00
# Epoch 482/500
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 1.3207 - val_accuracy: 0.0000e+00
# Epoch 483/500
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 1.3209 - val_accuracy: 0.0000e+00
# Epoch 484/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 1.3211 - val_accuracy: 0.0000e+00
# Epoch 485/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 1.3214 - val_accuracy: 0.0000e+00
# Epoch 486/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 1.3216 - val_accuracy: 0.0000e+00
# Epoch 487/500
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 1.3219 - val_accuracy: 0.0000e+00
# Epoch 488/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.3221 - val_accuracy: 0.0000e+00
# Epoch 489/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 1.3224 - val_accuracy: 0.0000e+00
# Epoch 490/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 1.3226 - val_accuracy: 0.0000e+00
# Epoch 491/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 1.3228 - val_accuracy: 0.0000e+00
# Epoch 492/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 1.3231 - val_accuracy: 0.0000e+00
# Epoch 493/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 1.3233 - val_accuracy: 0.0000e+00
# Epoch 494/500
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 1.3236 - val_accuracy: 0.0000e+00
# Epoch 495/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 1.3238 - val_accuracy: 0.0000e+00
# Epoch 496/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 1.3240 - val_accuracy: 0.0000e+00
# Epoch 497/500
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 1.3243 - val_accuracy: 0.0000e+00
# Epoch 498/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 1.3245 - val_accuracy: 0.0000e+00
# Epoch 499/500
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 1.3247 - val_accuracy: 0.0000e+00
# Epoch 500/500
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 1.3250 - val_accuracy: 0.0000e+00
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, esDAimag, clases_map):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )

        # sólo muestra las imágenes no generadas por DA
        if not esDAimag[i]:
          strTitulo = 'Real: ' + clReal + ' / RNA: ' 
          strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

          # muestra comparación con la imagen
          fig = plt.figure()
          fig.suptitle( strTitulo )
          ax1 = fig.add_subplot(121)
          plot_image( x[i] )
          
          plt.tight_layout()
          fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, esDAimag_train, clases_map)
# Out:
# *** Resultados con datos de Entrenamiento:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.75      0.86         8
#   versicolor       0.78      0.88      0.82         8
#    virginica       0.89      1.00      0.94         8
#
#     accuracy                           0.88        24
#    macro avg       0.89      0.88      0.87        24
# weighted avg       0.89      0.88      0.87        24
#
#
# Matriz de Confusión:
#               p:setosa  p:versicolor  p:virginica
# r:setosa             6             2            0
# r:versicolor         0             7            1
# r:virginica          0             0            8
#
#
#
# >Resultados:

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
#@title Probar red entrenada con datos de prueba
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, esDAimag_test, clases_map)
# Out:
# 1/1 [==============================] - 0s 15ms/step - loss: 0.8694 - accuracy: 0.4444
#
# >Evaluación del Modelo:
#     - Error:  0.8693777918815613
#     - Exactitud:  44.44444477558136
#
#
#
#
# *** Resultados con datos de Prueba:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#       setosa       1.00      0.33      0.50         3
#   versicolor       0.50      1.00      0.67         3
#    virginica       0.00      0.00      0.00         3
#
#     accuracy                           0.44         9
#    macro avg       0.50      0.44      0.39         9
# weighted avg       0.50      0.44      0.39         9
#
#
# Matriz de Confusión:
#               p:setosa  p:versicolor  p:virginica
# r:setosa             1             0            2
# r:versicolor         0             3            0
# r:virginica          0             3            0
#
#
#
# >Resultados:
